# %% [markdown]
# ### Scrapping Completo

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import pandas as pd
import re

# %%
# 1. Función para extraer datos genéricos desde etiquetas HTML
def extraer_datos(soup, tag, attrs):
    """
    Extrae el texto de todas las etiquetas HTML coincidentes con el tag y los atributos dados.

    Parameters:
    soup (bs4.BeautifulSoup): Objeto BeautifulSoup del contenido HTML.
    tag (str): El nombre de la etiqueta HTML que deseas buscar.
    attrs (dict): Un diccionario de atributos para identificar las etiquetas.

    Returns:
    list: Lista con los textos extraídos.
    """
    elementos = soup.find_all(tag, attrs=attrs)
    return [elemento.text.strip() if elemento else None for elemento in elementos]

# 2. Función para normalizar nombres de columnas
def normalizar_nombres_columnas(df):
    """
    Normaliza los nombres de las columnas del DataFrame, convirtiéndolos a mayúsculas.
    """
    df.columns = df.columns.str.upper()
    return df

# 3. Función para Encontrar caracteres: Funcion genérica para adaptarla
def buscar_numero_en(df, col_donde_sebusca, antes_de=None, despues_de=None):
    """
    Busca un número en la columna `col_metraje` de un DataFrame, especificando un patrón antes y/o después del número.
    
    Parameters:
    df (pd.DataFrame): El DataFrame donde se realiza la búsqueda.
    col_metraje (str): El nombre de la columna donde buscar el patrón.
    antes_de (str): El patrón que aparece antes del número (opcional).
    despues_de (str): El patrón que aparece después del número (opcional).
    
    Returns:
    pd.Series: Serie con los números encontrados.
    """
    
    # Crear la expresión regular
    # Si no se especifica "antes_de", solo busca basado en "despues_de"
    # Si no se especifica "despues_de", solo busca basado en "antes_de"
    if antes_de and despues_de:
        regex = rf'{re.escape(despues_de)}\s*(\d+)\s*{re.escape(antes_de)}'
    elif despues_de:
        regex = rf'{re.escape(despues_de)}\s*(\d+)'
    elif antes_de:
        regex = rf'(\d+)\s*{re.escape(antes_de)}'
    else:
        raise ValueError("Debes especificar al menos 'antes_de' o 'despues_de'.")
    
    # Aplicar la búsqueda de la expresión regular en la columna especificada
    return df[col_donde_sebusca].apply(lambda x: re.search(regex, x).group(1) if re.search(regex, x) else None)

# 4. Función para buscar un número entre patrones opcionales
def buscar_numero_en_precio(df, col_donde_sebusca, antes_de=None, despues_de=None):
    """
    Busca un número en la columna `col_metraje` de un DataFrame, especificando un patrón antes y/o después del número.
    Convierte números con separadores de miles (e.g., "125,500") en enteros (125500).
    
    Parameters:
    df (pd.DataFrame): El DataFrame donde se realiza la búsqueda.
    col_metraje (str): El nombre de la columna donde buscar el patrón.
    antes_de (str): El patrón que aparece antes del número (opcional).
    despues_de (str): El patrón que aparece después del número (opcional).
    
    Returns:
    pd.Series: Serie con los números encontrados.
    """
    
    # Crear la expresión regular para encontrar el número, considerando los patrones antes y/o después
    if antes_de and despues_de:
        regex = rf'{re.escape(despues_de)}\s*(\d{{1,3}}(?:,\d{{3}})*)\s*{re.escape(antes_de)}'
    elif despues_de:
        regex = rf'{re.escape(despues_de)}\s*(\d{{1,3}}(?:,\d{{3}})*)'
    elif antes_de:
        regex = rf'(\d{{1,3}}(?:,\d{{3}})*)\s*{re.escape(antes_de)}'
    else:
        raise ValueError("Debes especificar al menos 'antes_de' o 'despues_de'.")

    # Aplicar la expresión regular y limpiar el número
    return df[col_donde_sebusca].apply(lambda x: int(re.sub(r',', '', re.search(regex, x).group(1))) if re.search(regex, x) else None)


# 5. Función para limpiar precios y extraer monedas
def limpiar_precio(df, col_precio='PRECIO_DESDE'):
    """
    Limpia la columna de precios, detectando la moneda (Soles o Dólares) y extrayendo los valores numéricos.
    """
    df['Precio'] = df[col_precio].astype(str)
    df['Moneda_soles'] = df['Precio'].apply(lambda x: "Soles" if 'S/' in x else None)
    df['Moneda_dolares'] = df['Precio'].apply(lambda x: "Dólares" if 'USD' in x else None)
    
    #df['Precio_soles'] = df['Precio'].apply(lambda x: re.findall(r'\d+', x)[0] if 'S/' in x else None)
    df['Precio_soles'] = df.apply(lambda x: re.findall(r'\d+', x['Precio'])[0] if x['Moneda_soles'] else None, axis=1)

    #df['Precio_dolares'] = df['Precio'].apply(lambda x: re.findall(r'\d+', x)[0] if 'USD' in x else None)
    df['Precio_dolares'] = buscar_numero_en_precio(df, col_donde_sebusca = col_precio, despues_de='USD')
    
    # Convertir a tipo numérico
    df['Precio_soles'] = pd.to_numeric(df['Precio_soles'], errors='coerce')*1000.0
    df['Precio_dolares'] = pd.to_numeric(df['Precio_dolares'], errors='coerce')
    
    # Eliminar cualquier columna adicional si es necesario
    if 'Precio' in df.columns:
        df.drop(columns=['Precio'], inplace=True)
    
    return df

# 6. Función para limpiar ubicación
def limpiar_ubicacion(df, col_ubicacion='UBICACION', distritos=None):
    """
    Limpia la columna de ubicación eliminando distritos no deseados y caracteres especiales.
    """
    if distritos is None:
        distritos = ['Comas','COMAS','comas', 'Breña','BREÑA', 'Lima', 'Peru', 'Perú', 'SAN MIGUEL', 'LIMA', 'PERU']
    
    def limpiar_calle(ubicacion, distritos):
        for distrito in distritos:
            ubicacion = re.sub(rf'\b{distrito}\b', '', ubicacion) # Usamos \b para asegurarnos de que elimine el distrito cuando sea una palabra completa
            ubicacion = re.sub(distrito, '', ubicacion) # Eliminamos los casos donde el distrito pueda estar pegado a otras palabras
        
        ubicacion = re.sub(r'[.,;:!?\s]+$', '', ubicacion).strip()  # Eliminar cualquier signo de puntuación al final de la cadena
        ubicacion = re.sub(r'\s+', ' ', ubicacion).strip() # Eliminar espacios extras
        return ubicacion if ubicacion else None

    df['Calle'] = df[col_ubicacion].apply(lambda x: limpiar_calle(x, distritos) if isinstance(x, str) else None)
    return df

# 7. Función para extraer metraje y características adicionales
def extraer_metraje(df, col_metraje='METRAJE'):
    """
    Extrae información de metraje, unidades y dormitorios de la columna metraje.
    """
    """ df['Metraje'] = df[col_metraje].apply(lambda x: re.search(r'\d+ m²', x).group() if isinstance(x, str) else None)
    df['Dormitorios'] = df[col_metraje].apply(lambda x: re.search(r'\d+ dorm.', x).group() if isinstance(x, str) else None)
    return df """
    # Usando la función genérica para extraer diferentes valores
    df['Unidades'] = buscar_numero_en(df, col_metraje, antes_de='un.')
    df['Dormitorios'] = buscar_numero_en(df, col_metraje, antes_de='dorm.')
    df['Metraje_desde'] = buscar_numero_en(df, col_metraje, antes_de='a', despues_de='dorm.')
    df['Metraje_hasta'] = buscar_numero_en(df, col_metraje, antes_de='m²')
    df['Baños'] = buscar_numero_en(df, col_metraje, antes_de='baño')
    df['Estacionamientos'] = buscar_numero_en(df, col_metraje, antes_de='esta')
    
    # Convertir los resultados a numéricos donde sea necesario
    df['Unidades'] = pd.to_numeric(df['Unidades'], errors='coerce')
    df['Dormitorios'] = pd.to_numeric(df['Dormitorios'], errors='coerce')
    df['Metraje_desde'] = pd.to_numeric(df['Metraje_desde'], errors='coerce')
    df['Metraje_hasta'] = pd.to_numeric(df['Metraje_hasta'], errors='coerce')
    df['Baños'] = pd.to_numeric(df['Baños'], errors='coerce')
    df['Estacionamientos'] = pd.to_numeric(df['Estacionamientos'], errors='coerce')

    print(df.info())
    return df

# 8. Función para Cálculos de S/ o $ por m2
def añadir_calculos(df):
    df['Precio por m2 soles ref desde'] = round(df['Precio_soles']/df['Metraje_hasta'],0)
    df['Precio por m2 soles ref hasta'] = round(df['Precio_soles']/df['Metraje_desde'],0)
    
    if df['Precio_dolares'] is not None:
        df['Precio por m2 dol ref desde'] = round(df['Precio_dolares']/df['Metraje_hasta'],0)
        df['Precio por m2 dol ref hasta'] = round(df['Precio_dolares']/df['Metraje_desde'],0)
    
    return df    

# 9. Función para exportar a Excel

def exportar_excel(df, nombre_file, proyecto):
    DATA_ANALYTICS = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/"
    #BDVIVA = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/BD VIVA/ESTUDIOS DE PROYECTOS/BUSINESS INTELLIGENCE CON SCRAPPING/SCRAPPING DE PDMAR/BD de Internet Jugadores/"
    nombre_file = nombre_file + " "+ proyecto
    ubicacion_final_baseglobal = DATA_ANALYTICS + "BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/" + nombre_file + ".xlsx"
    #ubicacion_final_carpeta_proyecto = DATA_ANALYTICS + "ESTUDIOS DE PROYECTOS/BUSINESS INTELLIGENCE CON SCRAPPING/SCRAPPING DE LINCE/BD de Internet Jugadores/" + nombre_file + ".xlsx"
    #DATA DEL MERCADO CON SCRAPPING
    print(f"Exportando archivo a: {ubicacion_final_baseglobal}")
    df.to_excel(ubicacion_final_baseglobal, index=False)
    #print(f"Exportando archivo a: {ubicacion_final_carpeta_proyecto}")
    #df.to_excel(ubicacion_final_carpeta_proyecto, index=False)
    print("Archivo exportado exitosamente.")

# 8. Función principal de scraping y creación del DataFrame
def scraping_selenium(url):
    driver = webdriver.Chrome()
    driver.get(url)
    
    contenido = driver.page_source
    soup = bs(contenido, 'html.parser')
    driver.quit() # Cerrar navegador
    
    # Extraer datos usando las funciones genéricas
    titulo_sucio = extraer_datos(soup, "div", {"class": "caption"}) # 1
    
    # Crear el DataFrame
    data = {
        "TITULO": titulo_sucio
    }
    df = pd.DataFrame(data)

    # Limpiar y procesar los datos
    df = normalizar_nombres_columnas(df)
    return df
# Out:
# <>:135: SyntaxWarning: invalid escape sequence '\d'
# <>:135: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\diego.dinatale\AppData\Local\Temp\ipykernel_27888\3284646049.py:135: SyntaxWarning: invalid escape sequence '\d'
#   """ df['Metraje'] = df[col_metraje].apply(lambda x: re.search(r'\d+ m²', x).group() if isinstance(x, str) else None)

# %% [markdown]
# # DETALLAR

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

# 1. Levantar el driver y obtener el HTML
driver = webdriver.Chrome()
driver.get(url1)
html = driver.page_source
driver.quit()

# 2. Parsear con BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# 3. Imprimir el HTML completo (o parte de él)
print(soup.prettify()[:1000])   # solo los primeros 1.000 caracteres

# 4. Ver todas las etiquetas <div> con clase "caption"
for div in soup.find_all("div", class_="caption"):
    print(div)
    print("—" * 40)

# 5. Buscar y mostrar todas las etiquetas que contengan la palabra ‘Dormitorio’
import re
for tag in soup.find_all(text=re.compile(r"Dormitorios?", re.IGNORECASE)):
    print(tag.parent)  # muestra el elemento padre HTML donde aparece el texto
    print("—" * 40)
# Out:
# <html class="js flexbox canvas canvastext webgl no-touch geolocation postmessage no-websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths" lang="es">
#  <head>
#   <meta content="" http-equiv="origin-trial"/>
#   <style>
#    #nav-flat,#nav-duplex{    height: auto !important;}.ficha_proyecto1  .label-success {    background: #ECFDF3;    color: #12B76A;    padding: .4em .8em .4em;
# <div class="caption"> <p class="disponible"><a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59441" onclick="send_evento_modelo();" style="color:#000;">7 unidades disponibles                      </a></p> <div class="row"> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59441" onclick="send_evento_modelo();" style="color:#000"> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Modelo</span> <span class="detalle" style="font-size:14px">1D</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Piso</span> <span class="detalle">Entre 2 al  21</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Dormitorios</span> <span class="detalle">1 dorm.</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Área</span> <span class="detalle">40.28                                                m2</span></div> </a> <br class="clearfix"/> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59441" onclick="send_evento_modelo();" style="color:#000"><h3 class="detalle_precio col-md-12"><span>Precio desde</span> <br/>S/ 239,262</h3></a> </div> <p><a class="btn btn-default link-cta" href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59441" onclick="send_evento_modelo();" role="button">Cotiza ahora</a></p> </div>
# ————————————————————————————————————————
# <div class="caption"> <p class="disponible"><a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59442" onclick="send_evento_modelo();" style="color:red;">5 unidades disponibles                      </a></p> <div class="row"> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59442" onclick="send_evento_modelo();" style="color:#000"> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Modelo</span> <span class="detalle" style="font-size:14px">3D</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Piso</span> <span class="detalle">2, 3, 23</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Dormitorios</span> <span class="detalle">3 dorm.</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Área</span> <span class="detalle">65.02                                                m2</span></div> </a> <br class="clearfix"/> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59442" onclick="send_evento_modelo();" style="color:#000"><h3 class="detalle_precio col-md-12"><span>Precio desde</span> <br/>S/ 304,730</h3></a> </div> <p><a class="btn btn-default link-cta" href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59442" onclick="send_evento_modelo();" role="button">Cotiza ahora</a></p> </div>
# ————————————————————————————————————————
# <div class="caption"> <p class="disponible"><a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59443" onclick="send_evento_modelo();" style="color:#000;">13 unidades disponibles                      </a></p> <div class="row"> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59443" onclick="send_evento_modelo();" style="color:#000"> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Modelo</span> <span class="detalle" style="font-size:14px">3D+S</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Piso</span> <span class="detalle">Entre 3 al  23</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Dormitorios</span> <span class="detalle">3 dorm.</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Área</span> <span class="detalle">70.31                                                m2</span></div> </a> <br class="clearfix"/> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59443" onclick="send_evento_modelo();" style="color:#000"><h3 class="detalle_precio col-md-12"><span>Precio desde</span> <br/>S/ 361,031</h3></a> </div> <p><a class="btn btn-default link-cta" href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59443" onclick="send_evento_modelo();" role="button">Cotiza ahora</a></p> </div>
# ————————————————————————————————————————
# <div class="caption"> <p class="disponible"><a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59444" onclick="send_evento_modelo();" style="color:#000;">28 unidades disponibles                      </a></p> <div class="row"> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59444" onclick="send_evento_modelo();" style="color:#000"> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Modelo</span> <span class="detalle" style="font-size:14px">2D</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Piso</span> <span class="detalle">Entre 2 al  23</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Dormitorios</span> <span class="detalle">2 dorm.</span></div> <div class="col-sm-12 col-md-12 col-xs-12"><span class="detalle_cabecera">Área</span> <span class="detalle">49.93                                                m2</span></div> </a> <br class="clearfix"/> <a href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59444" onclick="send_evento_modelo();" style="color:#000"><h3 class="detalle_precio col-md-12"><span>Precio desde</span> <br/>S/ 258,815</h3></a> </div> <p><a class="btn btn-default link-cta" href="https://nexoinmobiliario.pe/cotizar/2825-gran-central-colonial-ii-59444" onclick="send_evento_modelo();" role="button">Cotiza ahora</a></p> </div>
# ————————————————————————————————————————
# <div class="caption"> <h3>Concepto Urban Park</h3> <p class="desde"> Desde</p> <h4>S/. 470,694</h4> <p class="direccion"><i class="fas fa-map-marker-alt"></i> Av. Petit Thouars 1140<br/>Cercado de lima</p> <p><a class="btn btn-primary btn-block" href="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2727-concepto-urban-park-cercado-de-lima-lima-lima-imagina" onclick="evento_te_recomendamos()" role="button">Ver Proyecto <i class="fas fa-chevron-right"></i></a> </p> </div>
# ————————————————————————————————————————
# <div class="caption"> <h3>Urban Tower 3</h3> <p class="desde"> Desde</p> <h4>S/. 265,778</h4> <p class="direccion"><i class="fas fa-map-marker-alt"></i> Avenida Mariano Cornejo 1824<br/>Cercado de lima</p> <p><a class="btn btn-primary btn-block" href="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3001-urban-tower-3-cercado-de-lima-lima-lima-quatro-inmobiliaria" onclick="evento_te_recomendamos()" role="button">Ver Proyecto <i class="fas fa-chevron-right"></i></a> </p> </div>
# ————————————————————————————————————————
# <div class="caption"> <h3>Invent Tirado</h3> <p class="desde"> Desde</p> <h4>S/. 411,957</h4> <p class="direccion"><i class="fas fa-map-marker-alt"></i> Tirado 629<br/>Cercado de lima</p> <p><a class="btn btn-primary btn-block" href="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2253-invent-tirado-cercado-de-lima-lima-lima-invent" onclick="evento_te_recomendamos()" role="button">Ver Proyecto <i class="fas fa-chevron-right"></i></a> </p> </div>
# ————————————————————————————————————————
# <script type="application/ld+json">
#                 {
#                 "@context": "https://schema.org",
#                 "@type": "house",
#                 "name": "Gran Central Colonial II",
#                 "image":"https://e.nexoinmobiliario.pe/customers/los-portales-construye-s-a-c/2825-gran-central-colonial-ii/departamentos-cercado-de-lima-67ad0a3988f67_b.jpg",
#                 "url": "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos",
#                 "logo": "https://e.nexoinmobiliario.pe/customers/los-portales-construye-s-a-c/2825-gran-central-colonial-2/logo-gran-central-colonial-2-20230418171500.jpg",
#                 "description": "Los Portales Departamentos te trae departamentos en Cercado de lima de 40.28 a 70.31 m2 con 1 a 3 dormitorios. Acceso a Gimnasio y más. Etapa: En construcción.",
#                 "geo":
#                     {
#                     "@type":"geocoordinates",
#                     "address":"Av. Óscar R. Benavides 2140, Cercado de Lima - Cercado de lima",
#                     "addresscountry": "PE"
#                     },
#                 "numberofrooms":
#                     {
#                         "@type":"quantitativevalue",
#                         "maxvalue":"3",
#                         "minvalue": "1",
#                         "unittext": "Dormitorios"
#                     },
#                     "floorsize":
#                         {
#                         "@type":"quantitativevalue",
#                         "maxvalue":"70.31",
#                         "minvalue": "40.28",
#                         "unitcode": "MTK"
#                         }
#                     }
#                 },
#                 {
#                 "@type": "RealEstateAgent",
#                 "name": "Los Portales Departamentos",
#                 "image":"https://e.nexoinmobiliario.pe/customers/los-portales-construye-s-a-c/logo-350-20231027061808.jpg",
#                 "url": "https://nexoinmobiliario.pe/inmobiliaria/los-portales-construye-s-a-c",
#                 "logo": "https://e.nexoinmobiliario.pe/customers/los-portales-construye-s-a-c/logo-350-20231027061808.jpg",
#                 "description": "Conoce los proyectos en venta de Los Portales Departamentos. Proyecto Gran Jardín Ticino 2 en Santa Anita. Proyecto Gran Parque Las Flores en San Juan De Lurigancho. Cotiza online.",
#                 "pricerange": "S/. 244,500 - S/. 310,030",
#                 "legalname": "Los Portales Departamentos",
#                     "knowslanguage":
#                         [
#                             {
#                             "@type": "Language",
#                             "name": "Spanish"
#                             },
#                             {
#                             "@type": "Language",
#                             "name": "English"
#                             }
#                         ],
#                 "memberof":
#                     {
#                     "@type": "Organization",
#                     "name": "Nexo Inmobiliario",
#                     "description": "En Nexo Inmobiliario encontrarás miles de departamentos en venta, lotes, casas y oficinas de estreno a nivel nacional. Visítanos y cotiza en minutos.",
#                     "url": "https://nexoinmobiliario.pe/",
#                     "telephone": "+51017134288",
#                     "email": "info@nexoinmobiliario.pe",
#                     "legalname": "Nexo Inmobiliario S.A.",
#                     "knowslanguage":
#                         [
#                             {
#                             "@type": "Language",
#                             "name": "Spanish"
#                             },
#                             {
#                             "@type": "Language",
#                             "name": "English"
#                             }
#                         ]
#                     }
#                 }
#             </script>
# ————————————————————————————————————————
# <div class="col-xs-6 col-sm-6 col-md-6">Dormitorios: </div>
# ————————————————————————————————————————
# <p><!-- <i class="fas fa-couch"></i>--> <img src="https://luisrodriguez.pe/demos/nexoinmobiliario/dormitorio.png"/>1 a 3 dormitorios</p>
# ————————————————————————————————————————
# <strong>Dormitorios</strong>
# ————————————————————————————————————————
# <a class="descending" data-sort="bedroom">Dormitorios</a>
# ————————————————————————————————————————
# <span class="detalle_cabecera">Dormitorios</span>
# ————————————————————————————————————————
# <span class="detalle_cabecera">Dormitorios</span>
# ————————————————————————————————————————
# <span class="detalle_cabecera">Dormitorios</span>
# ————————————————————————————————————————
# <span class="detalle_cabecera">Dormitorios</span>
# ————————————————————————————————————————
# <script charset="" id="" type="text/javascript">function send_evento_modelo(){dataLayer.push({event:"interacciones","interacciones-categoria":"ficha de proyecto","interacciones-accion":"click","interacciones-etiqueta":"\u00a1cotiza ahora!",content_group:"ficha de proyecto"})}function send_evento_zoom_img(){dataLayer.push({event:"interacciones","interacciones-categoria":"ficha de proyecto","interacciones-accion":"click","interacciones-etiqueta":"zoom img",content_group:"ficha de proyecto"})}
# function send_evento_inmobiliaria_logo(){dataLayer.push({event:"interacciones","interacciones-categoria":"ficha de proyecto","interacciones-accion":"click","interacciones-etiqueta":"inmobiliaria logo",content_group:"ficha de proyecto"})}var css="\x3cstyle\x3e#nav-flat,#nav-duplex{    height: auto !important;}.ficha_proyecto1  .label-success {    background: #ECFDF3;    color: #12B76A;    padding: .4em .8em .4em;    font-size: 12px;}.breadcrumb-ficha-proyecto\x3eli+li:before {    content: '\\2794' !important;    color: #98A2B3 !important;}.ct-ficha-proyecto .breadcrumb-ficha-proyecto a {    font-size: 11px !important;    color: #98A2B3 !important;}.ct-ficha-proyecto .content_tool_share {    display: none !important;}.ficha_proyecto1 p {    line-height: 30px;}.ficha_proyecto1 {    padding-bottom: 20px;    padding-top: 20px;}.ficha_proyecto1 h2.precio {    font-size: 25px;    font-family: 'neosans_medium';    font-weight: bold;    padding-bottom: 5px;    padding-top: 10px;}.ficha_proyecto1 .precio_referencial {    font-size: 14px;    color: #98A2B3;}.ficha_proyecto1 i.fa-map-marker-alt,.ficha_proyecto2 i.fa-map-marker-alt {    color: #F29003;    font-size: 18px;}.ficha_proyecto1 p.direccion,.ficha_proyecto2 p.direccion {    color: #000;    font-weight: 600;}.ficha_proyecto1 p.direccion a,.ficha_proyecto1 .inmobiliaria-logo a,.ficha_proyecto2 p.direccion a{    color: #F29003;    margin-left: 10px;}.proyecto-detalle {    padding-top: 20px;    background: #EAECF5;    border-radius: 10px;    padding-bottom: 20px;    margin-top: 12px;    color: #000;}.proyecto-detalle i {    color: #4E5BA6;    margin-right: 2px;    font-size: 25px;}.proyecto-detalle p {    font-size: 11px;}.row.proyecto-detalle {    margin-left: 0px;    margin-right: 0px;}.Project-description.description_project_main.clearfix,#cuadro_fix,.add-padding-description, .Project-areas-list.list-unstyled,.Project-description hr {    display: none;}.Project-description {    margin-bottom: 0px !important;}#modelsAvailable.Project-description.modelsProjectDesktop {    padding-top: 0px !important;}.row.proyecto-detalle hr {    width: 95%;    border: 0px;    height: 1px;    background: #98A2B3;}.ficha_proyecto2 {    padding-bottom: 40px;}.ficha_proyecto2 h2 {    font-size: 18px;    font-family: Gotham;    font-weight: 800;    color: #000;    padding-bottom: 20px;}.iframe-mapa {        padding-top: 20px;}.ficha_proyecto2 p {        font-size: 14px;        line-height: 22px;}.ct-ficha-proyecto {    display: block !important;}@media screen and (max-width: 992px) {    #Project-map{        display: none !important;    }        #cont_ficha_desktop .col-md-4.col-md-push-8.nopadding{        display: none !important;    }    #cont_ficha_desktop .Project-header.row{        display: none !important;    }    #cont_ficha_desktop .Project-gallery{        display: none !important;    }    .ct-ficha-proyecto {        margin-top: 0px !important;    }}.ct-detail-project-movil .Project-header.row .Project-header-title,.ct-detail-project-movil .Project-header.row .Project-menu .share,.ct-detail-project-movil .Project-header.row .Project-header-address.street,.ct-detail-project-movil .Project-header.row .Project-header-address.urb,.ct-detail-project-movil .Project-header.row .Project-price-movil.row.no-margin,.ct-detail-project-movil .Project-header.row .Project-toogle, .ct-detail-project-movil .Project-header.row .projectLogoInmobiliaria,.ct-detail-project-movil .Project-header.row .Project-signed.col-xs-12, .ct-detail-project-movil .Project-header.row  .update-date.text-center{    display: none !important;}@media screen and (max-width: 767px) {    .Project-available-preview {        display: none !important;    }    /*.bx-info-table.bx-info-table-center {        display: none !important;    }    .Project-available-actions{        display: none !important;    }*/}@media screen and (max-width: 992px) {    .proyectos-flat {        display: block !important;    }        /*.content-bx-scroll.active{      ...
# document.querySelector("head").insertAdjacentHTML("afterbegin",css);document.querySelectorAll(".Project-available-model").forEach(function(a){a.setAttribute("data-type","regular")});document.querySelectorAll("#nav-flat .Project-available-model").forEach(function(a){a.setAttribute("data-type","flat")});document.querySelectorAll("#nav-duplex .Project-available-model").forEach(function(a){a.setAttribute("data-type","duplex")});
# document.querySelectorAll("#nav-triplex .Project-available-model").forEach(function(a){a.setAttribute("data-type","triplex")});var regex=/Mobi|Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i;
# if(regex.test(navigator.userAgent)){var listItems=document.querySelectorAll(".desplegarCamposTipoFiltro")[1].querySelectorAll(".list-unstyled li"),datos=[];Array.prototype.forEach.call(listItems,function(a){var b=a.querySelectorAll("div");b.length===2&&(a=b[0].innerText.replace(":","").trim().toLowerCase(),b=b[1].innerText.trim(),datos.push({index:a,value:b}))});var precio_referencial="",precio=document.querySelectorAll(".detail-price-movil p")[0].innerText;precio=precio.replace(".","");document.querySelectorAll(".detail-price-movil p")[1]!=
# void 0&&(precio_referencial=document.querySelectorAll(".detail-price-movil p")[1].innerText);var direccion=document.querySelector(".ct-detail-project-movil p.Project-header-address").innerText}else{var rows=document.querySelectorAll("#cont_ficha_desktop .bx-data-project.box-st")[0].querySelectorAll("table tr");datos=[];Array.prototype.forEach.call(rows,function(a){var b=a.querySelectorAll("td");b.length===2&&(a=b[0].innerText.trim().toLowerCase(),b=b[1].innerText.trim(),a!==""&&datos.push({index:a,
# value:b}))});precio_referencial="";precio=document.querySelector(".Project-header-price strong").innerText;precio=precio.replace(".","");document.querySelector(".bx-title-price .title-price strong")!=null&&(precio_referencial=document.querySelector(".bx-title-price .title-price strong").innerText);direccion=document.querySelector(".Project-header-address").innerText}var estado,area_total,dormitorios,fecha_entrega,tipo_inmueble,financiamiento,area_techada,inmobiliaria_logo,inmobiliaria_perfil;
# document.querySelector("figure.Project-inmobiliaria__logo img")!=null&&(inmobiliaria_logo=document.querySelector("figure.Project-inmobiliaria__logo img").getAttribute("src"));document.querySelector("figure.Project-inmobiliaria__logo a")!=null&&(inmobiliaria_perfil=document.querySelector("figure.Project-inmobiliaria__logo a").getAttribute("href"));for(var i=0;i<datos.length;i++)if(datos[i].index==="etapa del proyecto"){estado=datos[i].value;break}
# for(i=0;i<datos.length;i++)if(datos[i].index==="\u00e1rea techada"){area_techada=datos[i].value;break}for(i=0;i<datos.length;i++)if(datos[i].index==="\u00e1rea total"){area_total=datos[i].value;break}for(i=0;i<datos.length;i++)if(datos[i].index==="dormitorios"){dormitorios=datos[i].value;break}for(i=0;i<datos.length;i++)if(datos[i].index==="fecha de entrega"){fecha_entrega=datos[i].value;break}for(i=0;i<datos.length;i++)if(datos[i].index==="tipo de inmueble"){tipo_inmueble=datos[i].value;break}
# for(i=0;i<datos.length;i++)if(datos[i].index==="financiamiento"){financiamiento=datos[i].value;break}document.querySelector(".breadcrumb.breadcrumb-ficha-proyecto li").innerHTML='\x3ca href\x3d"https://nexoinmobiliario.pe/"\x3e\x3ci style\x3d"font-size: 15px;" class\x3d"fas fa-home"\x3e\x3c/i\x3e\x3c/a\x3e';var html_ficha_proyecto1="";html_ficha_proyecto1+='\x3cdiv class\x3d"ficha_proyecto1"\x3e';html_ficha_proyecto1+='     \x3cdiv class\x3d"row"\x3e';html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-12"\x3e';
# html_ficha_proyecto1+='           \x3cspan class\x3d"label label-success"\x3e'+estado+"\x3c/span\x3e";html_ficha_proyecto1+="        \x3c/div\x3e";html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-6 col-sm-6 col-xs-12"\x3e';html_ficha_proyecto1+='            \x3ch2 class\x3d"precio"\x3ePrecio desde '+precio+"\x3c/h2\x3e";precio_referencial!=""&&(html_ficha_proyecto1+='            \x3cp class\x3d"precio_referencial"\x3eValor referencial\x26nbsp;'+precio_referencial+"\x3c/p\x3e");
# html_ficha_proyecto1+='            \x3cp class\x3d"direccion"\x3e\x3ci class\x3d"fas fa-map-marker-alt"\x3e\x3c/i\x3e '+direccion;html_ficha_proyecto1=regex.test(navigator.userAgent)?html_ficha_proyecto1+'               \x3ca href\x3d"javascript:void(0);" onclick\x3d"document.querySelector(\'.Project-menu .btn-option-menu[value\x3dmapa]\').click()"\x3eVer mapa\x3c/a\x3e':html_ficha_proyecto1+'               \x3ca href\x3d"#Project-map" \x3eVer mapa\x3c/a\x3e';html_ficha_proyecto1+="            \x3c/p\x3e";
# html_ficha_proyecto1+="        \x3c/div\x3e";html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-6 col-sm-6 col-xs-12"\x3e';html_ficha_proyecto1+='                   \x3cdiv class\x3d" col-xs-6 col-md-12 col-sm-12 "\x3e\x3cdiv class\x3d"financiamiento"\x3e\x3cspan\x3eFinanciamiento\x3c/span\x3e '+financiamiento+"\x3c/div\x3e\x3c/div\x3e";
# /prueba/.test(window.location.href)&&(html_ficha_proyecto1+='                   \x3cdiv class\x3d"inmobiliaria-logo col-xs-6 col-md-12 col-sm-12 "\x3e\x3ca href\x3d"'+inmobiliaria_perfil+'" onclick\x3d"send_evento_inmobiliaria_logo();"\x3e\x3cimg src\x3d"'+inmobiliaria_logo+'"\x3e\x3c/a\x3e\x3cbr /\x3e\x3ca href\x3d"'+inmobiliaria_perfil+'" onclick\x3d"send_evento_inmobiliaria_logo();"\x3eVer otros proyectos \x3e\x3c/a\x3e\x3c/div\x3e');html_ficha_proyecto1+="        \x3c/div\x3e";
# html_ficha_proyecto1+="    \x3c/div\x3e";html_ficha_proyecto1+='    \x3cdiv class\x3d"row proyecto-detalle"\x3e';html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-3 col-xs-6" style\x3d"height: 30px;"\x3e';html_ficha_proyecto1+='            \x3cp\x3e\x3ci class\x3d"fas fa-calendar-alt"\x3e\x3c/i\x3e '+fecha_entrega+"\x3c/p\x3e";html_ficha_proyecto1+="        \x3c/div\x3e";html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-3  col-xs-6"\x3e';
# html_ficha_proyecto1+='            \x3cp\x3e \x3cimg style\x3d"margin-right: 9px; width: 24px; margin-top: -6px;" src\x3d"https://luisrodriguez.pe/demos/nexoinmobiliario/medidas.png" /\x3e'+area_total+"\x3c/p\x3e";html_ficha_proyecto1+="        \x3c/div\x3e";html_ficha_proyecto1+='         \x3cdiv class\x3d"col-md-3  col-xs-6"\x3e';
# html_ficha_proyecto1+='            \x3cp\x3e \x3cimg style\x3d"margin-right: 9px; width: 24px; margin-top: -6px;"  src\x3d"https://luisrodriguez.pe/demos/nexoinmobiliario/departamentos.png" /\x3e'+tipo_inmueble+"\x3c/p\x3e";html_ficha_proyecto1+="        \x3c/div\x3e ";html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-3  col-xs-6"\x3e';
# tipo_inmueble=="Departamento"&&(html_ficha_proyecto1+='            \x3cp\x3e\x3c!-- \x3ci class\x3d"fas fa-couch"\x3e\x3c/i\x3e--\x3e \x3cimg src\x3d"https://luisrodriguez.pe/demos/nexoinmobiliario/dormitorio.png" /\x3e'+dormitorios+" dormitorios\x3c/p\x3e");html_ficha_proyecto1+="        \x3c/div\x3e";html_ficha_proyecto1+="    \x3c/div\x3e";html_ficha_proyecto1+='    \x3cdiv class\x3d"row"\x3e';html_ficha_proyecto1+='        \x3cdiv class\x3d"col-md-12"\x3e';html_ficha_proyecto1+="           \x3chr /\x3e";
# html_ficha_proyecto1+="        \x3c/div\x3e";html_ficha_proyecto1+="    \x3c/div\x3e";html_ficha_proyecto1+="\x3c/div\x3e";document.querySelector(".content_tool_share").insertAdjacentHTML("afterend",html_ficha_proyecto1);var descripcion;document.querySelector(".Project-description-p.short")!=null?descripcion=document.querySelector(".Project-description-p.short").innerText:document.querySelector(".Project-description-p")!=null&&(descripcion=document.querySelector(".Project-description-p").innerText);
# descripcion=descripcion.trim();var direccion_completa=document.querySelectorAll(".Project-header-address")[2].innerText+" "+document.querySelectorAll(".Project-header-address")[3].innerText;
# setTimeout(function(){var a="";a+='\x3cdiv class\x3d"ficha_proyecto2"\x3e';a+='    \x3cdiv class\x3d"row"\x3e';a+='        \x3cdiv class\x3d"col-md-12"\x3e';a+="           \x3chr /\x3e";a+="        \x3c/div\x3e";a+="    \x3c/div\x3e";a+='     \x3cdiv class\x3d"row"\x3e';a+='        \x3cdiv class\x3d"col-md-12"\x3e';a+="            \x3ch2\x3eDescripci\u00f3n\x3c/h2\x3e";document.querySelector(".Project-description .video")!=null?(a+='            \x3cdiv class\x3d"col-md-12 descripcion-proyecto-col"\x3e   ',
# a+='                   \x3cdiv class\x3d"descripcion-proyecto-col-1 video-youtube"\x3e\x3cdiv class\x3d"embed-responsive embed-responsive-16by9"\x3e\x3ciframe class\x3d"embed-responsive-item" src\x3d""\x3e\x3c/iframe\x3e\x3c/div\x3e\x3c/div\x3e',a+='                   \x3cp class\x3d"descripcion-proyecto short"\x3e'+descripcion+"\x3c/p\x3e",a+='                 \x3ca class\x3d"view-more-v2"\x3eLeer la descripci\u00f3n completa \x3ci class\x3d"fas fa-chevron-down"\x3e\x3c/i\x3e\x3c/a\x3e\x3ca class\x3d"view-less2-v2"\x3eVer menos \x3ci class\x3d"fas fa-chevron-up"\x3e\x3c/i\x3e\x3c/a\x3e',
# a+="            \x3c/div\x3e"):(a+='            \x3cp class\x3d"descripcion-proyecto short"\x3e'+descripcion+"\x3c/p\x3e",a+='            \x3ca class\x3d"view-more-v2"\x3eLeer la descripci\u00f3n completa \x3ci class\x3d"fas fa-chevron-down"\x3e\x3c/i\x3e\x3c/a\x3e',a+='            \x3ca class\x3d"view-less2-v2"\x3eVer menos \x3ci class\x3d"fas fa-chevron-up"\x3e\x3c/i\x3e\x3c/a\x3e');a+="        \x3c/div\x3e";a+="    \x3c/div\x3e";a+='    \x3cdiv class\x3d"row"\x3e';a+='        \x3cdiv class\x3d"col-md-12"\x3e';
# a+="           \x3chr /\x3e";a+="        \x3c/div\x3e";a+="    \x3c/div\x3e";var b=[];document.querySelectorAll(".Project-information ul.Project-areas-list li").forEach(function(f,g){b[g]=f.innerText});a+='     \x3cdiv class\x3d"row" id\x3d"area_comunes"\x3e';a+='        \x3cdiv class\x3d"col-md-12"\x3e';a+="            \x3ch2\x3e\u00c1reas comunes\x3c/h2\x3e";a+='            \x3cp class\x3d"descripcion-proyecto "\x3e'+b.join(", ")+"\x3c/p\x3e";a+="        \x3c/div\x3e";a+="    \x3c/div\x3e";a+='    \x3cdiv class\x3d"row"\x3e';
# a+='        \x3cdiv class\x3d"col-md-12"\x3e';a+="           \x3chr /\x3e";a+="        \x3c/div\x3e";a+="    \x3c/div\x3e";a+='     \x3cdiv class\x3d"row" id\x3d"proyecto_mapa"\x3e';a+='        \x3cdiv class\x3d"col-md-12"\x3e';a+="            \x3ch2\x3eUbicaci\u00f3n del proyecto\x3c/h2\x3e";a+='            \x3cp class\x3d"direccion"\x3e\x3ci class\x3d"fas fa-map-marker-alt"\x3e\x3c/i\x3e '+direccion_completa+"\x3c/p\x3e";a+="        \x3c/div\x3e";a+="    \x3c/div\x3e";a+="\x3c/div\x3e";document.querySelector(".Project-buttons-actions").insertAdjacentHTML("beforebegin",
# a);var c=document.querySelector(".view-more-v2"),d=document.querySelector(".view-less2-v2"),e=document.querySelector(".descripcion-proyecto");c.addEventListener("click",function(){e.style.maxHeight="none";c.style.display="none";d.style.display="inline";e.style.overflow="initial";e.classList.remove("short")});d.addEventListener("click",function(){e.style.maxHeight="160px";c.style.display="inline";d.style.display="none";e.style.overflow="hidden";e.classList.add("short")});var h=setInterval(function(){console.log("esperando que el video youtube este listo!");
# var f=document.querySelector("iframe#videoProject_youtube_iframe"),g=document.querySelector(".video-youtube");f!=null&g!=null&&(f=f.getAttribute("src"),iframe_video_new=document.querySelector(".embed-responsive-item"),f=f.replace("controls\x3d0","controls\x3d1"),iframe_video_new.setAttribute("src",f),clearInterval(h))},1E3)},1500);
# for(var tipos=["flat","duplex","triplex","regular"],index_tipos=0;index_tipos<tipos.length;index_tipos++){var html_ficha_proyecto3="",items_flat=[],items=[],items_duplex=[],items_regular=[],html_ficha_proyecto3_="";document.querySelectorAll(".Project-available-model[data-type\x3d'"+tipos[index_tipos]+"']").forEach(function(a,b){a.getAttribute("data-type");a.querySelector(".Project-available-preview a")!=null?(img_zoom=a.querySelector(".Project-available-preview a").getAttribute("data-links"),img_zoom=
# img_zoom.split(",")[0],mapa_href="https://e.nexoinmobiliario.pe/customers/"+img_zoom,mapa_img=a.querySelector(".Project-available-preview a img").getAttribute("src")):mapa_img=mapa_href="";if(regex.test(navigator.userAgent)){var c=document.querySelectorAll(".projectListProperty a.no-view-property .text-unit")[b].innerText;var d=c.match(/\d+/)}else c=a.querySelector(".Project-available-actions .text-unit").innerHTML,d=c.match(/\d+/);c=d[0];d=a.querySelector(".Project-available-actions a")!=null?a.querySelector(".Project-available-actions a").getAttribute("href"):
# "";a.querySelector(".bottom-info span.name_tipology")!=null&&a.querySelector(".bottom-info span.name_tipology");if(a.querySelector(".bottom-info span.num_pisos")!=null){var e=a.querySelector(".bottom-info span.num_pisos").innerText;e=e.replaceAll("Pisos:","");e=e.replaceAll("Piso:","");e=e.trim()}else e="";var h=a.querySelector(".bottom-info span.bedroom")!=null?a.querySelector(".bottom-info span.bedroom").innerText:"";var f=a.querySelector(".bottom-info span.area")!=null?a.querySelector(".bottom-info span.area").innerText:
# "";if(a.querySelector(".bottom-info span.price")!=null){var g=a.querySelector(".bottom-info span.price").innerText.trim();precio=precio.replace(".","")}else g="";var k=a.querySelector(".name_tipology")!=null?a.querySelector(".name_tipology").innerText.replace(/\n/g,"").trim():"";a=mapa_href;var l=mapa_img;h+=" dorm.";html_ficha_proyecto3_+='       \x3cdiv class\x3d"thumbnail-container col-sm-4 col-md-4 col-xs-12" data-item\x3d"'+b+'"\x3e';html_ficha_proyecto3_+='           \x3cdiv class\x3d"thumbnail"\x3e';
# l!=""?(html_ficha_proyecto3_+='               \x3ca href\x3d"javascript:void(0)" onclick\x3d"send_evento_zoom_img();my_zoom(\''+tipos[index_tipos]+"','"+b+'\');" class\x3d"zoom" data-img\x3d"'+b+'"\x3e',html_ficha_proyecto3_+='                   \x3cimg src\x3d"'+a+'" class\x3d"img-responsive" ',html_ficha_proyecto3_=regex.test(navigator.userAgent)?html_ficha_proyecto3_+'               style\x3d"height:224.55px" ':html_ficha_proyecto3_+'               style\x3d"height:149.33px" ',html_ficha_proyecto3_+=
# "                   /\x3e",html_ficha_proyecto3_+="               \x3c/a\x3e"):html_ficha_proyecto3_=regex.test(navigator.userAgent)?html_ficha_proyecto3_+'               \x3cdiv style\x3d"height:224.55px"\x3e\x3c/div\x3e':html_ficha_proyecto3_+'               \x3cdiv style\x3d"height:149.33px"\x3e\x3c/div\x3e';html_ficha_proyecto3_+='                    \x3cdiv class\x3d"caption"\x3e';b=c<=5?"red;":"#000;";html_ficha_proyecto3_+='                       \x3cp class\x3d"disponible"\x3e\x3ca href\x3d"'+
# d+'" style\x3d"color:'+b+'" onclick\x3d"send_evento_modelo();"\x3e'+c;html_ficha_proyecto3_=c>1?html_ficha_proyecto3_+" unidades disponibles":html_ficha_proyecto3_+" unidad disponible";b=k.length>11?11:14;html_ficha_proyecto3_+="                      \x3c/a\x3e\x3c/p\x3e";html_ficha_proyecto3_+='                       \x3cdiv class\x3d"row"\x3e';html_ficha_proyecto3_+='                           \x3ca href\x3d"'+d+'" style\x3d"color:#000"  onclick\x3d"send_evento_modelo();"\x3e';html_ficha_proyecto3_+=
# '                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3eModelo\x3c/span\x3e \x3cspan class\x3d"detalle" style\x3d"font-size:'+b+'px"\x3e'+k+"\x3c/span\x3e\x3c/div\x3e";tipo_inmueble=="Departamento"?(html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3ePiso\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+e+"\x3c/span\x3e\x3c/div\x3e",html_ficha_proyecto3_+=
# '                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3eDormitorios\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+h+"\x3c/span\x3e\x3c/div\x3e",html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3e\u00c1rea\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+f+"\x3c/span\x3e\x3c/div\x3e"):tipo_inmueble=="Casa"?(html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3e\u00c1rea\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+
# f+"\x3c/span\x3e\x3c/div\x3e",html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3eDormitorios\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+h+"\x3c/span\x3e\x3c/div\x3e"):tipo_inmueble=="Lote"?html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3e\u00c1rea\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+f+"\x3c/span\x3e\x3c/div\x3e":
# tipo_inmueble=="Oficina"&&(html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3ePiso\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+e+"\x3c/span\x3e\x3c/div\x3e",html_ficha_proyecto3_+='                              \x3cdiv class\x3d"col-sm-12 col-md-12 col-xs-12"\x3e\x3cspan class\x3d"detalle_cabecera"\x3e\u00c1rea\x3c/span\x3e  \x3cspan class\x3d"detalle"\x3e'+f+"\x3c/span\x3e\x3c/div\x3e");html_ficha_proyecto3_+=
# "                           \x3c/a\x3e";html_ficha_proyecto3_+='                           \x3cbr class\x3d"clearfix "/\x3e';html_ficha_proyecto3_+='                           \x3ca href\x3d"'+d+'" style\x3d"color:#000"  onclick\x3d"send_evento_modelo();"\x3e\x3ch3 class\x3d"detalle_precio col-md-12 "\x3e\x3cspan\x3ePrecio desde\x3c/span\x3e \x3cbr/\x3e'+g+"\x3c/h3\x3e\x3c/a\x3e";html_ficha_proyecto3_+="                       \x3c/div\x3e";html_ficha_proyecto3_+='                       \x3cp\x3e\x3ca href\x3d"'+
# d+'"  onclick\x3d"send_evento_modelo();"  class\x3d"btn btn-default link-cta" role\x3d"button"\x3eCotiza ahora\x3c/a\x3e\x3c/p\x3e';html_ficha_proyecto3_+="                   \x3c/div\x3e";html_ficha_proyecto3_+="           \x3c/div\x3e";regex.test(navigator.userAgent)&&(html_ficha_proyecto3_+='       \x3cdiv class\x3d"item_adicional"\x3e \x3c/div\x3e');html_ficha_proyecto3_+="       \x3c/div\x3e";items.push(html_ficha_proyecto3_);html_ficha_proyecto3_=""});if(document.querySelectorAll(".Project-available-model[data-type\x3d'"+
# tipos[index_tipos]+"']").length){html_ficha_proyecto3+='    \x3cdiv class\x3d"carrusel-custom"\x3e ';regex.test(navigator.userAgent)?(html_ficha_proyecto3+='        \x3cdiv id\x3d"carousel-reviews-'+tipos[index_tipos]+'" class\x3d"carousel slide" data-ride\x3d"carousel"\x3e ',html_ficha_proyecto3+='            \x3cdiv class\x3d"carousel-inner"\x3e'):(html_ficha_proyecto3+='        \x3cdiv id\x3d"carousel-reviews-'+tipos[index_tipos]+'"  \x3e ',html_ficha_proyecto3+='        \x3cdiv class\x3d"carousel-inner_"\x3e');
# var active="active",items_fixed=items;items=[];for(i=0;i<items_fixed.length;i+=1){var container_tmp=document.createElement("div");container_tmp.innerHTML=items_fixed[i];var element=container_tmp.querySelector('[data-item\x3d"'+i+'"]').outerHTML;items.push(element)}if(regex.test(navigator.userAgent))for(i=0;i<items.length;i+=1)html_ficha_proyecto3+='\x3cdiv class\x3d"item '+active+'"   data-type\x3d"'+tipos[index_tipos]+'"\x3e',i==0&&(active=""),container_tmp=document.createElement("div"),container_tmp.innerHTML=
# items[i],element=container_tmp.querySelector('[data-item\x3d"'+i+'"]').outerHTML,html_ficha_proyecto3+=element,html_ficha_proyecto3+="\x3c/div\x3e";else{var grupos=[],posicion_grupo=0,ii=0,visual="block",swich="";items.forEach(function(a,b){ii++;grupos[posicion_grupo]+=items[b];if(ii==3||items.length==b+1)posicion_grupo+=1,ii=0});console.log(grupos);console.log(grupos.length);for(i=0;i<grupos.length;i+=1)console.log(i),swich=i>1?"swich":"",i==2&&(visual="none"),html_ficha_proyecto3+='\x3cdiv class\x3d"item '+
# active+" "+swich+' " style\x3d"display:'+visual+'"\x3e',i==0&&(active=""),html_ficha_proyecto3+=grupos[i],html_ficha_proyecto3+="\x3c/div\x3e";grupos.length>2&&(html_ficha_proyecto3+='\x3cdiv class\x3d"col-md-12 text-left"\x3e\x3ca class\x3d"ver-mas-modelos mas" href\x3d"javascript:void(0)" onclick\x3d"ver_mas_modelos(\''+tipos[index_tipos]+'\',this);"  \x3ever m\u00e1s modelos \x3ci class\x3d"fas fa-chevron-down"\x3e\x3c/i\x3e\x3c/a\x3e\x3c/div\x3e')}html_ficha_proyecto3+="            \x3c/div\x3e";
# regex.test(navigator.userAgent)&&(html_ficha_proyecto3+='               \x3ca class\x3d"left carousel-control" href\x3d"#carousel-reviews-'+tipos[index_tipos]+'" role\x3d"button" data-slide\x3d"prev"\x3e',html_ficha_proyecto3+='                   \x3ci class\x3d"fas fa-chevron-left"\x3e\x3c/i\x3e',html_ficha_proyecto3+="               \x3c/a\x3e",html_ficha_proyecto3+='               \x3ca class\x3d"right carousel-control" href\x3d"#carousel-reviews-'+tipos[index_tipos]+'" role\x3d"button" data-slide\x3d"next"\x3e',
# html_ficha_proyecto3+='                   \x3ci class\x3d"fas fa-chevron-right"\x3e\x3c/i\x3e',html_ficha_proyecto3+="               \x3c/a\x3e");html_ficha_proyecto3+="        \x3c/div\x3e";html_ficha_proyecto3+="    \x3c/div\x3e";html_ficha_proyecto3=html_ficha_proyecto3.replaceAll("undefined","");console.log(tipos[index_tipos]);tipos[index_tipos]=="regular"?document.querySelector("#modelsAvailable #Project-lists").insertAdjacentHTML("afterbegin",html_ficha_proyecto3):tipos[index_tipos]=="flat"?
# document.querySelector("#nav-flat").insertAdjacentHTML("afterbegin",html_ficha_proyecto3):tipos[index_tipos]=="duplex"?document.querySelector("#nav-duplex").insertAdjacentHTML("afterbegin",html_ficha_proyecto3):tipos[index_tipos]=="triplex"&&document.querySelector("#nav-triplex").insertAdjacentHTML("afterbegin",html_ficha_proyecto3)}}html_ficha_proyecto4="";html_ficha_proyecto4+='\x3cdiv class\x3d"ficha_proyecto4"\x3e    ';html_ficha_proyecto4+='    \x3cdiv class\x3d"row"\x3e      ';
# html_ficha_proyecto4+='        \x3cdiv class\x3d"col-md-12"\x3e ';if(document.querySelector(".Project-inmobiliaria img")!=null)var inmobiliaria_img=document.querySelector(".Project-inmobiliaria img").getAttribute("src"),inmobiliaria_link=document.querySelector(".Project-inmobiliaria a").getAttribute("href"),inmobiliaria_nombre=document.querySelector(".Project-inmobiliaria h2").innerText;
# html_ficha_proyecto4+='        \x3cp class\x3d"inmobiliaria"\x3e \x3ca style\x3d"font-size: 14px; font-family: Gotham; font-weight: 800; color: #000;" target\x3d"_black" href\x3d"'+inmobiliaria_link+'"\x3e\x3cimg style\x3d"margin-bottom: 10px;float: left;margin-right: 10px;" width\x3d"90" alt\x3d"'+inmobiliaria_nombre+'" src\x3d"'+inmobiliaria_img+'"\x3e '+inmobiliaria_nombre+' \x3cbr\x3e\x3cspan style\x3d"  font-weight: 500; font-size: 12px; "\x3eVer otros proyectos \x26gt;\x3c/span\x3e \x3c/a\x3e\x3c/p\x3e \x3cbr style\x3d"clear: both;"\x3e';
# html_ficha_proyecto4+="            \x3ch2\x3eModelos disponibles\x3c/h2\x3e";html_ficha_proyecto4+="        \x3c/div\x3e";html_ficha_proyecto4+="    \x3c/div\x3e";html_ficha_proyecto4+="\x3c/div\x3e";document.querySelector("#Project-lists").insertAdjacentHTML("afterbegin",html_ficha_proyecto4);
# function ver_mas_modelos(a,b){var c=b;c.classList.contains("mas")?(c.classList.remove("mas"),c.classList.add("menos"),c.innerHTML='ver menos modelos \x3ci class\x3d"fas fa-chevron-up"\x3e\x3c/i\x3e'):c.classList.contains("menos")&&(c.classList.remove("menos"),c.classList.add("mas"),c.innerHTML='ver m\u00e1s modelos \x3ci class\x3d"fas fa-chevron-down"\x3e\x3c/i\x3e');document.querySelectorAll(".carrusel-custom .item.swich").forEach(function(d){c.classList.contains("menos")&&(d.style.display="block");
# c.classList.contains("mas")&&(d.style.display="none",window.location="#Project-lists")})}
# function my_zoom(a,b){a=="regular"?document.querySelectorAll("#modelsAvailable #Project-lists .Project-available-modelList.grid .Project-available-preview")[b].querySelectorAll("a")[1].click():document.querySelectorAll("#nav-"+a+" .Project-available-model .Project-available-preview")[b].querySelector("a")!=null&&document.querySelectorAll("#nav-"+a+" .Project-available-model .Project-available-preview")[b].querySelector("a").click()}
# $(".carousel").on("touchstart",function(a){var b=a.originalEvent.touches[0].pageX;$(this).one("touchmove",function(c){c=c.originalEvent.touches[0].pageX;var d=5;Math.floor(b-c)>d?$(this).carousel("next"):Math.floor(b-c)<-d&&$(this).carousel("prev")});$(this).on("touchend",function(){$(this).off("touchmove")})});</script>
# ————————————————————————————————————————
# C:\Users\diego.dinatale\AppData\Local\Temp\ipykernel_27888\2877309385.py:25: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for tag in soup.find_all(text=re.compile(r"Dormitorios?", re.IGNORECASE)):

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup as BS
from selenium import webdriver

class MarketScraper:
    """
    Clase para extracción, limpieza y análisis de datos de proyectos inmobiliarios.
    """
    def __init__(self, url=None, df=None):
        self.url = url
        self.df = df
        self.soup = None

    def _init_driver(self):
        driver = webdriver.Chrome()
        driver.get(self.url)
        content = driver.page_source
        driver.quit()
        self.soup = BS(content, 'html.parser')

    def extract_data(self, tag: str, attrs: dict) -> list:
        items = self.soup.find_all(tag, attrs=attrs)
        return [el.text.strip() for el in items]

    def normalize_columns(self):
        self.df.columns = self.df.columns.str.upper()
        return self

    def debug_dormitorios(self) -> list:
        """
        Método de depuración: devuelve el HTML de los elementos que contienen 'Dormitorios'.
        Útil para inspeccionar etiquetas antes de ajustar la extracción.
        """
        # Busca cualquier texto que contenga 'Dormitorio' (con o sin 's')
        matches = self.soup.find_all(text=re.compile(r'Dormitoris?', re.IGNORECASE))
        # Devuelve cadena HTML de cada elemento padre
        return [str(m.parent) for m in matches]

    def extract_title_features(self, title_col: str = 'TITULO'):
        def _parse(titulo):
            u = re.search(r'(\d+) unidad?', titulo)
            unidades = int(u.group(1)) if u else None
            m = re.search(r'(\w+)\sPiso', titulo)
            modelo = m.group(1) if m else None
            ep = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
            if ep:
                piso_desde, piso_hasta = int(ep.group(1)), int(ep.group(2))
                total_pisos = piso_hasta - piso_desde + 1
            else:
                pc = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
                if pc:
                    pisos_list = [int(p) for p in pc[0].split(', ')]
                    piso_desde, piso_hasta = min(pisos_list), max(pisos_list)
                    total_pisos = len(pisos_list)
                else:
                    piso_desde = piso_hasta = total_pisos = None
            d = re.search(r'(\d+) Dormitorios?', titulo)
            dormitorios = int(d.group(1)) if d else None
            a = re.search(r'Área ([\d.]+)', titulo)
            area = float(a.group(1)) if a else None
            p = re.search(r'Precio desde S/ ([\d,]+)', titulo)
            precio = float(p.group(1).replace(',', '')) if p else None
            return [unidades, modelo, piso_desde, piso_hasta, total_pisos, dormitorios, area, precio]
        cols = ['Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos',
                'Dormitorios', 'Area_m2', 'Precio_Desde_Soles']
        title_df = pd.DataFrame(self.df[title_col].astype(str).apply(_parse).tolist(), columns=cols)
        self.df = pd.concat([self.df, title_df], axis=1)
        self.df.dropna(how='all', subset=cols, inplace=True)
        return self

    def _build_regex(self, before: str = None, after: str = None, price: bool = False) -> str:
        num = r"\d{1,3}(?:,\d{3})*" if price else r"\d+"
        if before and after:
            return rf"{re.escape(after)}\s*({num})\s*{re.escape(before)}"
        if after:
            return rf"{re.escape(after)}\s*({num})"
        if before:
            return rf"({num})\s*{re.escape(before)}"
        raise ValueError("Se requiere al menos 'before' o 'after'.")

    def find_number(self, col: str, before: str = None, after: str = None, price: bool = False) -> pd.Series:
        regex = self._build_regex(before, after, price)
        return self.df[col].apply(lambda x: int(re.search(regex, str(x)).group(1).replace(',', ''))
                                  if re.search(regex, str(x)) else None)

    def clean_price(self, col: str = 'PRECIO_DESDE'):
        if col in self.df.columns:
            s = self.df[col].astype(str)
            self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles', False: None})
            self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares', False: None})
            self.df['Precio_soles'] = s.where(self.df['Moneda_soles'].notnull()) \
                .str.extract(r"(\d+)\b")[0].astype(float) * 1000
            self.df['Precio_dolares'] = self.find_number(col, after='USD', price=True)
        return self

    def clean_location(self, col: str = 'UBICACION', districts: list = None):
        if col in self.df.columns:
            if districts is None:
                districts = ['Comas', 'Breña', 'Lima', 'Peru', 'Perú', 'San Miguel']
            def _clean(text):
                if not isinstance(text, str):
                    return None
                for d in districts:
                    text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
                return re.sub(r"\s+", ' ', re.sub(r"[\.,;:!?]+$", '', text)).strip() or None
            self.df['Calle'] = self.df[col].apply(_clean)
        return self

    def extract_features(self, col: str = 'METRAJE'):
        if col in self.df.columns:
            keys = ['Unidades', 'Dormitorios', 'Metraje_desde', 'Metraje_hasta', 'Baños', 'Estacionamientos']
            patterns = [('un.', None), ('dorm.', None), ('a', 'dorm.'), ('m²', None), ('baño', None), ('esta', None)]
            for key, (before, after) in zip(keys, patterns):
                self.df[key] = pd.to_numeric(self.find_number(col, before=before, after=after), errors='coerce')
        return self

    def add_calculations(self):
        if 'Precio_soles' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_soles_desde'] = (self.df['Precio_soles'] / self.df['Metraje_hasta']).round()
        if 'Precio_soles' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_soles_hasta'] = (self.df['Precio_soles'] /

# %%
# Ejecutar la función principal con la URL deseada

# NEXO INMOBILIARIA
# 41 dptos
#url = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2907-alto-lima-park-cercado-de-lima-lima-lima-imagina"
url = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

""" url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3737-nova-cercado-de-lima-lima-lima-kallpa"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2213-checor-las-magnolias-cercado-de-lima-lima-lima-checor-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2715-central-park-cercado-de-lima-lima-lima-tribeca-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3008-amatista-cercado-de-lima-lima-lima-marte"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2660-alto-alborada-cercado-de-lima-lima-lima-imagina"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3035-jardines-de-santa-beatriz-etapa-ii-cercado-de-lima-lima-lima-tm-gestion-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3385-albamar-re-cercado-de-lima-lima-lima-albamar-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2888-duetto-846-fase-ii-cercado-de-lima-lima-lima-cantabria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3053-minimal-cercado-de-lima-lima-lima-grupo-tyc"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3381-novo-3-cercado-de-lima-lima-lima-my-home"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3011-torre-castelo-cercado-de-lima-lima-lima-capac-asociados"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1993-s14-apartments-cercado-de-lima-lima-lima-urbana-per%C3%BA"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2641-checor-las-dalias-cercado-de-lima-lima-lima-checor-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3186-helio-santa-beatriz-cercado-de-lima-lima-lima-padova"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3027-qantua-fase-1-cercado-de-lima-lima-lima-grupo-lar"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3321-centriqo-club-condomino-ecoamigable-cercado-de-lima-lima-lima-besco"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2912-nueva-metropolis-cercado-de-lima-lima-lima-invent"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2996-albamar-arenales-cercado-de-lima-lima-lima-albamar-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2767-ciudaris-i-iconik-park-cercado-de-lima-lima-lima-ciudaris"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3693-roble-cercado-de-lima-lima-lima-abril-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3453-cedro-33-cercado-de-lima-lima-lima-abril-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2647-alameda-central-condominio-cercado-de-lima-lima-lima-besco"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2727-concepto-urban-park-cercado-de-lima-lima-lima-imagina"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3684-albamar-bea-cercado-de-lima-lima-lima-albamar-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3001-urban-tower-3-cercado-de-lima-lima-lima-quatro-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3452-qantua-fase-2-cercado-de-lima-lima-lima-grupo-lar"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2324-park-living-cercado-de-lima-lima-lima-eureka"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2462-duetto-846-cercado-de-lima-lima-lima-cantabria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2850-pietra-centrale-cercado-de-lima-lima-lima-rumi-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3491-centrico-cercado-de-lima-lima-lima-grupo-mg"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1867-edificio-vista-verde-cercado-de-lima-lima-lima-grupo-mg"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2253-invent-tirado-cercado-de-lima-lima-lima-invent"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2907-alto-lima-park-cercado-de-lima-lima-lima-imagina"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2308-smart-a-cercado-de-lima-lima-lima-grupo-mg"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3209-tulipan-cercado-de-lima-lima-lima-abril-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3298-cool-living-cercado-de-lima-lima-lima-promsal"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1816-central-home-cercado-de-lima-lima-lima-casa-bonita"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2965-santorini-cercado-de-lima-lima-lima-brazil-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3466-evolution-cercado-de-lima-lima-lima-pisonay-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1866-edificio-los-pinos-iii-cercado-de-lima-lima-lima-grupo-mg"
"""

df = scraping_selenium(url)

# Actualización de la función para manejar los dos patrones adicionales
def limpiar_titulo_actualizado(titulo):
        # Buscar número de unidades disponibles
        #unidades = re.search(r'(\d+) unidades?', titulo)
        unidades = re.search(r'(\d+) unidad?', titulo)
        unidades_disponibles = int(unidades.group(1)) if unidades else None
        
        # Buscar el modelo (secuencia de palabras hasta 'Piso')
        modelo = re.search(r'(\w+)\sPiso', titulo)
        modelo_nombre = modelo.group(1) if modelo else None

        # Caso 1: Patrón "Entre X al Y"
        # entre_pisos = re.search(r'Entre (\d+) al (\d+)', titulo)
        entre_pisos = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
        if entre_pisos:
            piso_desde = int(entre_pisos.group(1))
            piso_hasta = int(entre_pisos.group(2))
            total_pisos = piso_hasta - piso_desde + 1
        else:
            # Caso 2: Patrón "Piso X, Y, Z"
            pisos_comas = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
            if pisos_comas:
                pisos = [int(piso) for piso in pisos_comas[0].split(', ')]
                piso_desde = min(pisos)
                piso_hasta = max(pisos)
                total_pisos = len(pisos)
            else:
                piso_desde, piso_hasta, total_pisos = None, None, None

        # Buscar dormitorios
        dormitorios = re.search(r'(\d+) Dormitorios?', titulo)
        dormitorios_num = int(dormitorios.group(1)) if dormitorios else None
        
        # Buscar área
        area = re.search(r'Área ([\d.]+)', titulo)
        area_m2 = float(area.group(1)) if area else None
        
        # Buscar precio
        precio = re.search(r'Precio desde S/ ([\d,]+)', titulo)
        precio_soles = float(precio.group(1).replace(',', '')) if precio else None
        
        return [unidades_disponibles, modelo_nombre, piso_desde, piso_hasta, total_pisos, dormitorios_num, area_m2, precio_soles]

    # Aplicar la función actualizada

df_comas_cleaned_actualizado = df['TITULO'].apply(limpiar_titulo_actualizado)
df_comas_cleaned_actualizado = pd.DataFrame(df_comas_cleaned_actualizado.tolist(), columns=[
    'Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos', 'Dormitorios', 'Area_m2', 'Precio_Desde_Soles'
])

df_comas_cleaned_actualizado = df_comas_cleaned_actualizado.dropna(axis=0, how='all')

exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Gran Central Colonial II 26_05_25")

# Mostrar el DataFrame resultante
print(df.head())
# Out:
# Exportando archivo a: C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/Lima Proyecto Gran Central Colonial II 26_05_25.xlsx
# Archivo exportado exitosamente.
#                                               TITULO
# 0  7 unidades disponibles                        ...
# 1  5 unidades disponibles                        ...
# 2  13 unidades disponibles                       ...
# 3  28 unidades disponibles                       ...
# 4  HELIO SANTA BEATRIZ  Desde S/. 244,600  Enriqu...

# %%
# Ejecutar la función principal con la URL deseada

# NEXO INMOBILIARIA
# 41 dptos
#url = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2907-alto-lima-park-cercado-de-lima-lima-lima-imagina"
url = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3737-nova-cercado-de-lima-lima-lima-kallpa"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2213-checor-las-magnolias-cercado-de-lima-lima-lima-checor-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2715-central-park-cercado-de-lima-lima-lima-tribeca-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3008-amatista-cercado-de-lima-lima-lima-marte"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2660-alto-alborada-cercado-de-lima-lima-lima-imagina"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3035-jardines-de-santa-beatriz-etapa-ii-cercado-de-lima-lima-lima-tm-gestion-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3385-albamar-re-cercado-de-lima-lima-lima-albamar-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2888-duetto-846-fase-ii-cercado-de-lima-lima-lima-cantabria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3053-minimal-cercado-de-lima-lima-lima-grupo-tyc"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3381-novo-3-cercado-de-lima-lima-lima-my-home"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3011-torre-castelo-cercado-de-lima-lima-lima-capac-asociados"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1993-s14-apartments-cercado-de-lima-lima-lima-urbana-per%C3%BA"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2641-checor-las-dalias-cercado-de-lima-lima-lima-checor-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3186-helio-santa-beatriz-cercado-de-lima-lima-lima-padova"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3027-qantua-fase-1-cercado-de-lima-lima-lima-grupo-lar"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3321-centriqo-club-condomino-ecoamigable-cercado-de-lima-lima-lima-besco"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2912-nueva-metropolis-cercado-de-lima-lima-lima-invent"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2996-albamar-arenales-cercado-de-lima-lima-lima-albamar-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2767-ciudaris-i-iconik-park-cercado-de-lima-lima-lima-ciudaris"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3693-roble-cercado-de-lima-lima-lima-abril-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3453-cedro-33-cercado-de-lima-lima-lima-abril-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2647-alameda-central-condominio-cercado-de-lima-lima-lima-besco"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2727-concepto-urban-park-cercado-de-lima-lima-lima-imagina"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3684-albamar-bea-cercado-de-lima-lima-lima-albamar-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3001-urban-tower-3-cercado-de-lima-lima-lima-quatro-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3452-qantua-fase-2-cercado-de-lima-lima-lima-grupo-lar"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2324-park-living-cercado-de-lima-lima-lima-eureka"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2462-duetto-846-cercado-de-lima-lima-lima-cantabria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2850-pietra-centrale-cercado-de-lima-lima-lima-rumi-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3491-centrico-cercado-de-lima-lima-lima-grupo-mg"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1867-edificio-vista-verde-cercado-de-lima-lima-lima-grupo-mg"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2253-invent-tirado-cercado-de-lima-lima-lima-invent"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2907-alto-lima-park-cercado-de-lima-lima-lima-imagina"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2308-smart-a-cercado-de-lima-lima-lima-grupo-mg"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3209-tulipan-cercado-de-lima-lima-lima-abril-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3298-cool-living-cercado-de-lima-lima-lima-promsal"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1816-central-home-cercado-de-lima-lima-lima-casa-bonita"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2965-santorini-cercado-de-lima-lima-lima-brazil-grupo-inmobiliario"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3466-evolution-cercado-de-lima-lima-lima-pisonay-inmobiliaria"
url ="https://nexoinmobiliario.pe/proyecto/venta-de-departamento-1866-edificio-los-pinos-iii-cercado-de-lima-lima-lima-grupo-mg"


df = scraping_selenium(url)

# Actualización de la función para manejar los dos patrones adicionales
def limpiar_titulo_actualizado(titulo):
        # Buscar número de unidades disponibles
        #unidades = re.search(r'(\d+) unidades?', titulo)
        unidades = re.search(r'(\d+) unidad?', titulo)
        unidades_disponibles = int(unidades.group(1)) if unidades else None
        
        # Buscar el modelo (secuencia de palabras hasta 'Piso')
        modelo = re.search(r'(\w+)\sPiso', titulo)
        modelo_nombre = modelo.group(1) if modelo else None

        # Caso 1: Patrón "Entre X al Y"
        # entre_pisos = re.search(r'Entre (\d+) al (\d+)', titulo)
        entre_pisos = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
        if entre_pisos:
            piso_desde = int(entre_pisos.group(1))
            piso_hasta = int(entre_pisos.group(2))
            total_pisos = piso_hasta - piso_desde + 1
        else:
            # Caso 2: Patrón "Piso X, Y, Z"
            pisos_comas = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
            if pisos_comas:
                pisos = [int(piso) for piso in pisos_comas[0].split(', ')]
                piso_desde = min(pisos)
                piso_hasta = max(pisos)
                total_pisos = len(pisos)
            else:
                piso_desde, piso_hasta, total_pisos = None, None, None

        # Buscar dormitorios
        dormitorios = re.search(r'(\d+) Dormitorios?', titulo)
        dormitorios_num = int(dormitorios.group(1)) if dormitorios else None
        
        # Buscar área
        area = re.search(r'Área ([\d.]+)', titulo)
        area_m2 = float(area.group(1)) if area else None
        
        # Buscar precio
        precio = re.search(r'Precio desde S/ ([\d,]+)', titulo)
        precio_soles = float(precio.group(1).replace(',', '')) if precio else None
        
        return [unidades_disponibles, modelo_nombre, piso_desde, piso_hasta, total_pisos, dormitorios_num, area_m2, precio_soles]

    # Aplicar la función actualizada

df_comas_cleaned_actualizado = df['TITULO'].apply(limpiar_titulo_actualizado)
df_comas_cleaned_actualizado = pd.DataFrame(df_comas_cleaned_actualizado.tolist(), columns=[
    'Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos', 'Dormitorios', 'Area_m2', 'Precio_Desde_Soles'
])

df_comas_cleaned_actualizado = df_comas_cleaned_actualizado.dropna(axis=0, how='all')

#Imagina
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Alto Lima Park 16_04_25")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Alto Lima Park 05_05_25")

#Abril
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Cedro 33 16_04_25")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Cedro 33 05_05_25")

#Alameda
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Alameda Central 16_04_25")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Alameda Central 05_05_05")

# Los Portales
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Gran Central Colonial II 16_04_25")
exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Gran Central Colonial II 05_05_25")

#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Albamar 16_04_25")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Céntriqo 16_04_25")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Céntriqo 05_05_05")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Alto Alborada 16_04_25")

#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Hanan")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Duetto 846")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Urban Tower 3")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Evolution")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "Amatista")
#exportar_excel(df_comas_cleaned_actualizado, nombre_file="Lima Proyecto", proyecto = "")


# Mostrar el DataFrame resultante
print(df.head())

# %% [markdown]
# ### VERSIÓN OOP

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup as BS
from selenium import webdriver

class MarketScraper:
    """
    Clase para extracción, limpieza y análisis de datos de proyectos inmobiliarios.
    """
    def __init__(self, url=None, df=None):
        self.url = url
        self.df = df
        self.soup = None

    def _init_driver(self):
        driver = webdriver.Chrome()
        driver.get(self.url)
        content = driver.page_source
        driver.quit()
        self.soup = BS(content, 'html.parser')

    def extract_data(self, tag: str, attrs: dict) -> list:
        """
        Extrae texto de etiquetas HTML según tag y atributos.
        """
        items = self.soup.find_all(tag, attrs=attrs)
        return [el.text.strip() for el in items]

    def normalize_columns(self):
        """
        Convierte nombres de columnas a mayúsculas.
        """
        self.df.columns = self.df.columns.str.upper()
        return self

    def _build_regex(self, before: str = None, after: str = None, price: bool = False) -> str:
        if price:
            num = r"\d{1,3}(?:,\d{3})*"
        else:
            num = r"\d+"
        if before and after:
            return rf"{re.escape(after)}\s*({num})\s*{re.escape(before)}"
        if after:
            return rf"{re.escape(after)}\s*({num})"
        if before:
            return rf"({num})\s*{re.escape(before)}"
        raise ValueError("Se requiere al menos 'before' o 'after'.")

    def find_number(self, col: str, before: str = None, after: str = None, price: bool = False) -> pd.Series:
        """
        Extrae números de una columna según patrones opcionales.
        """
        regex = self._build_regex(before, after, price)
        def _extract(x):
            m = re.search(regex, str(x))
            if m:
                val = m.group(1)
                return int(val.replace(',', '')) if price else int(val)
            return None
        return self.df[col].apply(_extract)

    def clean_price(self, col: str = 'PRECIO_DESDE'):
        """
        Extrae y convierte precios en soles y dólares.
        """
        s = self.df[col].astype(str)
        self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles'})
        self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares'})
        # extraer valores
        self.df['Precio_soles'] = s.where(self.df['Moneda_soles'].notna()) \
            .str.extract(r"(\d+)\b")[0].astype(float) * 1000
        self.df['Precio_dolares'] = self.find_number(col, after='USD', price=True)
        return self

    def clean_location(self, col: str = 'UBICACION', districts: list = None):
        """
        Elimina distritos y limpia texto de ubicación.
        """
        if districts is None:
            districts = ['Comas','Breña','Lima','Peru','Perú','San Miguel']
        def _clean(text):
            if not isinstance(text, str):
                return None
            for d in districts:
                text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
            text = re.sub(r"[\.,;:!?]+$", '', text).strip()
            return re.sub(r"\s+", ' ', text) or None
        self.df['Calle'] = self.df[col].apply(_clean)
        return self

    def extract_features(self, col: str = 'METRAJE'):
        """
        Extrae unidades, dormitorios, metraje, baños y estacionamientos.
        """
        self.df['Unidades'] = self.find_number(col, before='un.')
        self.df['Dormitorios'] = self.find_number(col, before='dorm.')
        self.df['Metraje_desde'] = self.find_number(col, before='a', after='dorm.')
        self.df['Metraje_hasta'] = self.find_number(col, before='m²')
        self.df['Baños'] = self.find_number(col, before='baño')
        self.df['Estacionamientos'] = self.find_number(col, before='esta')
        for c in ['Unidades','Dormitorios','Metraje_desde','Metraje_hasta','Baños','Estacionamientos']:
            self.df[c] = pd.to_numeric(self.df[c], errors='coerce')
        return self

    def add_calculations(self):
        """
        Añade precios por m2 en soles y dólares.
        """
        self.df['Precio m2_soles_desde'] = (self.df['Precio_soles'] / self.df['Metraje_hasta']).round()
        self.df['Precio m2_soles_hasta'] = (self.df['Precio_soles'] / self.df['Metraje_desde']).round()
        if 'Precio_dolares' in self.df:
            self.df['Precio m2_usd_desde'] = (self.df['Precio_dolares'] / self.df['Metraje_hasta']).round()
            self.df['Precio m2_usd_hasta'] = (self.df['Precio_dolares'] / self.df['Metraje_desde']).round()
        return self

    def export_to_excel(self, filename: str, project: str):
        """
        Exporta DataFrame a Excel en ruta configurada.
        """
        base = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/"  
        path = f"{base}BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/{filename} {project}.xlsx"
        print(f"Guardando en {path}")
        self.df.to_excel(path, index=False)
        print("Exportación exitosa.")
        return self

    def run(self, project: str, price_col: str = 'PRECIO_DESDE', loc_col: str = 'UBICACION', area_col: str = 'METRAJE') -> pd.DataFrame:
        """
        Flujo completo: scraping, limpieza, extracción de características y exportación.
        """
        self._init_driver()
        datos = self.extract_data('div', {'class': 'caption'})
        self.df = pd.DataFrame({'TITULO': datos})
        (self.normalize_columns()
             .clean_price(price_col)
             .clean_location(loc_col)
             .extract_features(area_col)
             .add_calculations()
             .export_to_excel('Datos_Scraping', project))
        return self.df

# %%
# Ejemplo de uso:
url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

scraper = MarketScraper(url=url1)
df_final = scraper.run(project="Proyecto Gran Central Colonial II 26_05_25")
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRECIO_DESDE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
#       2 url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"
#       4 scraper = MarketScraper(url=url1)
# ----> 5 df_final = scraper.run(project="Proyecto Gran Central Colonial II 26_05_25")
#       6 df_final
#
# Cell In[8], line 135, in MarketScraper.run(self, project, price_col, loc_col, area_col)
#     132 datos = self.extract_data('div', {'class': 'caption'})
#     133 self.df = pd.DataFrame({'TITULO': datos})
#     134 (self.normalize_columns()
# --> 135      .clean_price(price_col)
#     136      .clean_location(loc_col)
#     137      .extract_features(area_col)
#     138      .add_calculations()
#     139      .export_to_excel('Datos_Scraping', project))
#     140 return self.df
#
# Cell In[8], line 66, in MarketScraper.clean_price(self, col)
#      62 def clean_price(self, col: str = 'PRECIO_DESDE'):
#      63     """
#      64     Extrae y convierte precios en soles y dólares.
#      65     """
# ---> 66     s = self.df[col].astype(str)
#      67     self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles'})
#      68     self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares'})
#
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'PRECIO_DESDE'

# %% [markdown]
# ### VERSION 2

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup as BS
from selenium import webdriver

class MarketScraper:
    """
    Clase para extracción, limpieza y análisis de datos de proyectos inmobiliarios.
    """
    def __init__(self, url=None, df=None):
        self.url = url
        self.df = df
        self.soup = None

    def _init_driver(self):
        driver = webdriver.Chrome()
        driver.get(self.url)
        content = driver.page_source
        driver.quit()
        self.soup = BS(content, 'html.parser')

    def extract_data(self, tag: str, attrs: dict) -> list:
        """
        Extrae texto de etiquetas HTML según tag y atributos.
        """
        items = self.soup.find_all(tag, attrs=attrs)
        return [el.text.strip() for el in items]

    def normalize_columns(self):
        """
        Convierte nombres de columnas a mayúsculas.
        """
        self.df.columns = self.df.columns.str.upper()
        return self

    def extract_title_features(self, title_col: str = 'TITULO'):
        """
        Extrae información adicional del título: unidades, modelo, pisos, dormitorios, área y precio.
        """
        def _parse(titulo):
            # Unidades disponibles
            u = re.search(r'(\d+) unidad?', titulo)
            unidades = int(u.group(1)) if u else None
            # Modelo
            m = re.search(r'(\w+)\sPiso', titulo)
            modelo = m.group(1) if m else None
            # Rangos de pisos
            ep = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
            if ep:
                piso_desde = int(ep.group(1)); piso_hasta = int(ep.group(2))
                total_pisos = piso_hasta - piso_desde + 1
            else:
                pc = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
                if pc:
                    pisos_list = [int(p) for p in pc[0].split(', ')]
                    piso_desde = min(pisos_list); piso_hasta = max(pisos_list)
                    total_pisos = len(pisos_list)
                else:
                    piso_desde = piso_hasta = total_pisos = None
            # Dormitorios
            d = re.search(r'(\d+) Dormitorios?', titulo)
            dormitorios = int(d.group(1)) if d else None
            # Área m2
            a = re.search(r'Área ([\d.]+)', titulo)
            area = float(a.group(1)) if a else None
            # Precio desde
            p = re.search(r'Precio desde S/ ([\d,]+)', titulo)
            precio = float(p.group(1).replace(',', '')) if p else None
            return [unidades, modelo, piso_desde, piso_hasta, total_pisos, dormitorios, area, precio]
        # Aplicar y unir al DataFrame
        cols = ['Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos',
                'Dormitorios', 'Area_m2', 'Precio_Desde_Soles']
        title_df = pd.DataFrame(self.df[title_col].astype(str).apply(_parse).tolist(), columns=cols)
        self.df = pd.concat([self.df, title_df], axis=1)
        # Eliminar filas vacías completas
        self.df.dropna(how='all', subset=cols, inplace=True)
        return self

    def _build_regex(self, before: str = None, after: str = None, price: bool = False) -> str:
        if price:
            num = r"\d{1,3}(?:,\d{3})*"
        else:
            num = r"\d+"
        if before and after:
            return rf"{re.escape(after)}\s*({num})\s*{re.escape(before)}"
        if after:
            return rf"{re.escape(after)}\s*({num})"
        if before:
            return rf"({num})\s*{re.escape(before)}"
        raise ValueError("Se requiere al menos 'before' o 'after'.")

    def find_number(self, col: str, before: str = None, after: str = None, price: bool = False) -> pd.Series:
        """
        Extrae números de una columna según patrones opcionales.
        """
        regex = self._build_regex(before, after, price)
        def _extract(x):
            m = re.search(regex, str(x))
            if m:
                val = m.group(1)
                return int(val.replace(',', '')) if price else int(val)
            return None
        return self.df[col].apply(_extract)

    def clean_price(self, col: str = 'PRECIO_DESDE'):
        """
        Extrae y convierte precios en soles y dólares.
        """
        s = self.df[col].astype(str)
        self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles'})
        self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares'})
        self.df['Precio_soles'] = s.where(self.df['Moneda_soles'].notna()) \
            .str.extract(r"(\d+)\b")[0].astype(float) * 1000
        self.df['Precio_dolares'] = self.find_number(col, after='USD', price=True)
        return self

    def clean_location(self, col: str = 'UBICACION', districts: list = None):
        """
        Elimina distritos y limpia texto de ubicación.
        """
        if districts is None:
            districts = ['Comas','Breña','Lima','Peru','Perú','San Miguel']
        def _clean(text):
            if not isinstance(text, str):
                return None
            for d in districts:
                text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
            text = re.sub(r"[\.,;:!?]+$", '', text).strip()
            return re.sub(r"\s+", ' ', text) or None
        self.df['Calle'] = self.df[col].apply(_clean)
        return self

    def extract_features(self, col: str = 'METRAJE'):
        """
        Extrae unidades, dormitorios, metraje, baños y estacionamientos.
        """
        self.df['Unidades'] = self.find_number(col, before='un.')
        self.df['Dormitorios'] = self.find_number(col, before='dorm.')
        self.df['Metraje_desde'] = self.find_number(col, before='a', after='dorm.')
        self.df['Metraje_hasta'] = self.find_number(col, before='m²')
        self.df['Baños'] = self.find_number(col, before='baño')
        self.df['Estacionamientos'] = self.find_number(col, before='esta')
        for c in ['Unidades','Dormitorios','Metraje_desde','Metraje_hasta','Baños','Estacionamientos']:
            self.df[c] = pd.to_numeric(self.df[c], errors='coerce')
        return self

    def add_calculations(self):
        """
        Añade precios por m2 en soles y dólares.
        """
        self.df['Precio m2_soles_desde'] = (self.df['Precio_soles'] / self.df['Metraje_hasta']).round()
        self.df['Precio m2_soles_hasta'] = (self.df['Precio_soles'] / self.df['Metraje_desde']).round()
        if 'Precio_dolares' in self.df:
            self.df['Precio m2_usd_desde'] = (self.df['Precio_dolares'] / self.df['Metraje_hasta']).round()
            self.df['Precio m2_usd_hasta'] = (self.df['Precio_dolares'] / self.df['Metraje_desde']).round()
        return self

    def export_to_excel(self, filename: str, project: str):
        """
        Exporta DataFrame a Excel en ruta configurada.
        """
        base = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/"
        path = f"{base}BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/{filename} {project}.xlsx"
        print(f"Guardando en {path}")
        self.df.to_excel(path, index=False)
        print("Exportación exitosa.")
        return self

    def run(self, project: str, price_col: str = 'PRECIO_DESDE', loc_col: str = 'UBICACION', area_col: str = 'METRAJE') -> pd.DataFrame:
        """
        Flujo completo: scraping, limpieza, extracción de características y exportación.
        """
        self._init_driver()
        datos = self.extract_data('div', {'class': 'caption'})
        self.df = pd.DataFrame({'TITULO': datos})
        (self.normalize_columns()
             .extract_title_features()
             .clean_price(price_col)
             .clean_location(loc_col)
             .extract_features(area_col)
             .add_calculations()
             .export_to_excel('Datos_Scraping', project))
        return self.df

# %%
# Ejemplo de uso:
# scraper = MarketScraper(url="https://ejemplo.com")
# df_final = scraper.run(project="ProyectoX")

# Ejemplo de uso:
url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

scraper = MarketScraper(url=url1)
df_final = scraper.run(project="Proyecto1")
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRECIO_DESDE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 9
#       6 url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"
#       8 scraper = MarketScraper(url=url1)
# ----> 9 df_final = scraper.run(project="Proyecto1")
#      10 df_final
#
# Cell In[12], line 178, in MarketScraper.run(self, project, price_col, loc_col, area_col)
#     174 datos = self.extract_data('div', {'class': 'caption'})
#     175 self.df = pd.DataFrame({'TITULO': datos})
#     176 (self.normalize_columns()
#     177      .extract_title_features()
# --> 178      .clean_price(price_col)
#     179      .clean_location(loc_col)
#     180      .extract_features(area_col)
#     181      .add_calculations()
#     182      .export_to_excel('Datos_Scraping', project))
#     183 return self.df
#
# Cell In[12], line 109, in MarketScraper.clean_price(self, col)
#     105 def clean_price(self, col: str = 'PRECIO_DESDE'):
#     106     """
#     107     Extrae y convierte precios en soles y dólares.
#     108     """
# --> 109     s = self.df[col].astype(str)
#     110     self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles'})
#     111     self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares'})
#
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'PRECIO_DESDE'

# %% [markdown]
# ### VERSION 3

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup as BS
from selenium import webdriver

class MarketScraper:
    """
    Clase para extracción, limpieza y análisis de datos de proyectos inmobiliarios.
    """
    def __init__(self, url=None, df=None):
        self.url = url
        self.df = df
        self.soup = None

    def _init_driver(self):
        driver = webdriver.Chrome()
        driver.get(self.url)
        content = driver.page_source
        driver.quit()
        self.soup = BS(content, 'html.parser')

    def extract_data(self, tag: str, attrs: dict) -> list:
        """
        Extrae texto de etiquetas HTML según tag y atributos.
        """
        items = self.soup.find_all(tag, attrs=attrs)
        return [el.text.strip() for el in items]

    def normalize_columns(self):
        """
        Convierte nombres de columnas a mayúsculas.
        """
        self.df.columns = self.df.columns.str.upper()
        return self

    def extract_title_features(self, title_col: str = 'TITULO'):
        """
        Extrae información adicional del título: unidades, modelo, pisos, dormitorios, área y precio.
        """
        def _parse(titulo):
            u = re.search(r'(\d+) unidad?', titulo)
            unidades = int(u.group(1)) if u else None
            m = re.search(r'(\w+)\sPiso', titulo)
            modelo = m.group(1) if m else None
            ep = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
            if ep:
                piso_desde, piso_hasta = int(ep.group(1)), int(ep.group(2))
                total_pisos = piso_hasta - piso_desde + 1
            else:
                pc = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
                if pc:
                    pisos_list = [int(p) for p in pc[0].split(', ')]
                    piso_desde, piso_hasta = min(pisos_list), max(pisos_list)
                    total_pisos = len(pisos_list)
                else:
                    piso_desde = piso_hasta = total_pisos = None
            d = re.search(r'(\d+) Dormitorios?', titulo)
            dormitorios = int(d.group(1)) if d else None
            a = re.search(r'Área ([\d.]+)', titulo)
            area = float(a.group(1)) if a else None
            p = re.search(r'Precio desde S/ ([\d,]+)', titulo)
            precio = float(p.group(1).replace(',', '')) if p else None
            return [unidades, modelo, piso_desde, piso_hasta, total_pisos, dormitorios, area, precio]
        cols = ['Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos',
                'Dormitorios', 'Area_m2', 'Precio_Desde_Soles']
        title_df = pd.DataFrame(self.df[title_col].astype(str).apply(_parse).tolist(), columns=cols)
        self.df = pd.concat([self.df, title_df], axis=1)
        self.df.dropna(how='all', subset=cols, inplace=True)
        return self

    def _build_regex(self, before: str = None, after: str = None, price: bool = False) -> str:
        if price:
            num = r"\d{1,3}(?:,\d{3})*"
        else:
            num = r"\d+"
        if before and after:
            return rf"{re.escape(after)}\s*({num})\s*{re.escape(before)}"
        if after:
            return rf"{re.escape(after)}\s*({num})"
        if before:
            return rf"({num})\s*{re.escape(before)}"
        raise ValueError("Se requiere al menos 'before' o 'after'.")

    def find_number(self, col: str, before: str = None, after: str = None, price: bool = False) -> pd.Series:
        regex = self._build_regex(before, after, price)
        def _extract(x):
            m = re.search(regex, str(x))
            if m:
                val = m.group(1)
                return int(val.replace(',', '')) if price else int(val)
            return None
        return self.df[col].apply(_extract)

    def clean_price(self, col: str = 'PRECIO_DESDE'):
        """
        Extrae y convierte precios en soles y dólares si la columna existe.
        """
        if col not in self.df.columns:
            return self
        s = self.df[col].astype(str)
        self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles', False: None})
        self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares', False: None})
        self.df['Precio_soles'] = s.where(self.df['Moneda_soles'].notnull()) \
            .str.extract(r"(\d+)\b")[0].astype(float) * 1000
        self.df['Precio_dolares'] = self.find_number(col, after='USD', price=True)
        return self

    def clean_location(self, col: str = 'UBICACION', districts: list = None):
        if districts is None:
            districts = ['Comas','Breña','Lima','Peru','Perú','San Miguel']
        def _clean(text):
            if not isinstance(text, str):
                return None
            for d in districts:
                text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
            return re.sub(r"\s+", ' ', re.sub(r"[\.,;:!?]+$", '', text)).strip() or None
        self.df['Calle'] = self.df[col].apply(_clean)
        return self

    def extract_features(self, col: str = 'METRAJE'):
        keys = ['Unidades','Dormitorios','Metraje_desde','Metraje_hasta','Baños','Estacionamientos']
        patterns = [('un.', None), ('dorm.', None), ('a', 'dorm.'), ('m²', None), ('baño', None), ('esta', None)]
        for key, (before, after) in zip(keys, patterns):
            self.df[key] = pd.to_numeric(self.find_number(col, before=before, after=after), errors='coerce')
        return self

    def add_calculations(self):
        if 'Precio_soles' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_soles_desde'] = (self.df['Precio_soles'] / self.df['Metraje_hasta']).round()
        if 'Precio_soles' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_soles_hasta'] = (self.df['Precio_soles'] / self.df['Metraje_desde']).round()
        if 'Precio_dolares' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_usd_desde'] = (self.df['Precio_dolares'] / self.df['Metraje_hasta']).round()
        if 'Precio_dolares' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_usd_hasta'] = (self.df['Precio_dolares'] / self.df['Metraje_desde']).round()
        return self

    def export_to_excel(self, filename: str, project: str):
        base = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/"
        path = f"{base}BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/{filename} {project}.xlsx"
        print(f"Guardando en {path}")
        self.df.to_excel(path, index=False)
        print("Exportación exitosa.")
        return self

    def run(self, project: str, price_col: str = 'PRECIO_DESDE', loc_col: str = 'UBICACION', area_col: str = 'METRAJE') -> pd.DataFrame:
        self._init_driver()
        datos = self.extract_data('div', {'class': 'caption'})
        self.df = pd.DataFrame({'TITULO': datos})
        (self.normalize_columns()
             .extract_title_features()
             .clean_price(price_col)
             .clean_location(loc_col)
             .extract_features(area_col)
             .add_calculations()
             .export_to_excel('Datos_Scraping', project))
        return self.df

# Ejemplo de uso:
# scraper = MarketScraper(url="https://ejemplo.com")
# df_final = scraper.run(project="ProyectoX")

# %%
# Ejemplo de uso:
url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

scraper = MarketScraper(url=url1)
df_final = scraper.run(project="Proyecto1")
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UBICACION'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       2 url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"
#       4 scraper = MarketScraper(url=url1)
# ----> 5 df_final = scraper.run(project="Proyecto1")
#       6 df_final
#
# Cell In[14], line 153, in MarketScraper.run(self, project, price_col, loc_col, area_col)
#     148 datos = self.extract_data('div', {'class': 'caption'})
#     149 self.df = pd.DataFrame({'TITULO': datos})
#     150 (self.normalize_columns()
#     151      .extract_title_features()
#     152      .clean_price(price_col)
# --> 153      .clean_location(loc_col)
#     154      .extract_features(area_col)
#     155      .add_calculations()
#     156      .export_to_excel('Datos_Scraping', project))
#     157 return self.df
#
# Cell In[14], line 117, in MarketScraper.clean_location(self, col, districts)
#     115         text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
#     116     return re.sub(r"\s+", ' ', re.sub(r"[\.,;:!?]+$", '', text)).strip() or None
# --> 117 self.df['Calle'] = self.df[col].apply(_clean)
#     118 return self
#
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\diego.dinatale\OneDrive - Aenza\LOCAL_MACHINE\DATA_ANALYTICS\MODELOS DE EFICIENCIA DE LEADS\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'UBICACION'

# %% [markdown]
# ### VERSION 4

# %%
import re
import pandas as pd
from bs4 import BeautifulSoup as BS
from selenium import webdriver

class MarketScraper:
    """
    Clase para extracción, limpieza y análisis de datos de proyectos inmobiliarios.
    """
    def __init__(self, url=None, df=None):
        self.url = url
        self.df = df
        self.soup = None

    def _init_driver(self):
        driver = webdriver.Chrome()
        driver.get(self.url)
        content = driver.page_source
        driver.quit()
        self.soup = BS(content, 'html.parser')

    def extract_data(self, tag: str, attrs: dict) -> list:
        items = self.soup.find_all(tag, attrs=attrs)
        return [el.text.strip() for el in items]

    def normalize_columns(self):
        self.df.columns = self.df.columns.str.upper()
        return self

    def extract_title_features(self, title_col: str = 'TITULO'):
        def _parse(titulo):
            u = re.search(r'(\d+) unidad?', titulo)
            unidades = int(u.group(1)) if u else None
            m = re.search(r'(\w+)\sPiso', titulo)
            modelo = m.group(1) if m else None
            ep = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
            if ep:
                piso_desde, piso_hasta = int(ep.group(1)), int(ep.group(2))
                total_pisos = piso_hasta - piso_desde + 1
            else:
                pc = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
                if pc:
                    pisos_list = [int(p) for p in pc[0].split(', ')]
                    piso_desde, piso_hasta = min(pisos_list), max(pisos_list)
                    total_pisos = len(pisos_list)
                else:
                    piso_desde = piso_hasta = total_pisos = None
            d = re.search(r'(\d+) Dormitorios?', titulo)
            dormitorios = int(d.group(1)) if d else None
            a = re.search(r'Área ([\d.]+)', titulo)
            area = float(a.group(1)) if a else None
            p = re.search(r'Precio desde S/ ([\d,]+)', titulo)
            precio = float(p.group(1).replace(',', '')) if p else None
            return [unidades, modelo, piso_desde, piso_hasta, total_pisos, dormitorios, area, precio]
        cols = ['Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos',
                'Dormitorios', 'Area_m2', 'Precio_Desde_Soles']
        title_df = pd.DataFrame(self.df[title_col].astype(str).apply(_parse).tolist(), columns=cols)
        self.df = pd.concat([self.df, title_df], axis=1)
        self.df.dropna(how='all', subset=cols, inplace=True)
        return self

    def _build_regex(self, before: str = None, after: str = None, price: bool = False) -> str:
        num = r"\d{1,3}(?:,\d{3})*" if price else r"\d+"
        if before and after:
            return rf"{re.escape(after)}\s*({num})\s*{re.escape(before)}"
        if after:
            return rf"{re.escape(after)}\s*({num})"
        if before:
            return rf"({num})\s*{re.escape(before)}"
        raise ValueError("Se requiere al menos 'before' o 'after'.")

    def find_number(self, col: str, before: str = None, after: str = None, price: bool = False) -> pd.Series:
        regex = self._build_regex(before, after, price)
        return self.df[col].apply(lambda x: int(re.search(regex, str(x)).group(1).replace(',', ''))
                                  if re.search(regex, str(x)) else None)

    def clean_price(self, col: str = 'PRECIO_DESDE'):
        if col in self.df.columns:
            s = self.df[col].astype(str)
            self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles', False: None})
            self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares', False: None})
            self.df['Precio_soles'] = s.where(self.df['Moneda_soles'].notnull()) \
                .str.extract(r"(\d+)\b")[0].astype(float) * 1000
            self.df['Precio_dolares'] = self.find_number(col, after='USD', price=True)
        return self

    def clean_location(self, col: str = 'UBICACION', districts: list = None):
        if col in self.df.columns:
            if districts is None:
                districts = ['Comas', 'Breña', 'Lima', 'Peru', 'Perú', 'San Miguel']
            def _clean(text):
                if not isinstance(text, str):
                    return None
                for d in districts:
                    text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
                return re.sub(r"\s+", ' ', re.sub(r"[\.,;:!?]+$", '', text)).strip() or None
            self.df['Calle'] = self.df[col].apply(_clean)
        return self

    def extract_features(self, col: str = 'METRAJE'):
        if col in self.df.columns:
            keys = ['Unidades', 'Dormitorios', 'Metraje_desde', 'Metraje_hasta', 'Baños', 'Estacionamientos']
            patterns = [('un.', None), ('dorm.', None), ('a', 'dorm.'), ('m²', None), ('baño', None), ('esta', None)]
            for key, (before, after) in zip(keys, patterns):
                self.df[key] = pd.to_numeric(self.find_number(col, before=before, after=after), errors='coerce')
        return self

    def add_calculations(self):
        if 'Precio_soles' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_soles_desde'] = (self.df['Precio_soles'] / self.df['Metraje_hasta']).round()
        if 'Precio_soles' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_soles_hasta'] = (self.df['Precio_soles'] / self.df['Metraje_desde']).round()
        if 'Precio_dolares' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_usd_desde'] = (self.df['Precio_dolares'] / self.df['Metraje_hasta']).round()
        if 'Precio_dolares' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_usd_hasta'] = (self.df['Precio_dolares'] / self.df['Metraje_desde']).round()
        return self

    def export_to_excel(self, filename: str, project: str):
        base = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/"
        path = f"{base}BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/{filename} {project}.xlsx"
        print(f"Guardando en {path}")
        self.df.to_excel(path, index=False)
        print("Exportación exitosa.")
        return self

    def run(self, project: str, price_col: str = 'PRECIO_DESDE', loc_col: str = 'UBICACION', area_col: str = 'METRAJE') -> pd.DataFrame:
        self._init_driver()
        datos = self.extract_data('div', {'class': 'caption'})
        self.df = pd.DataFrame({'TITULO': datos})
        (self.normalize_columns()
             .extract_title_features()
             .clean_price(price_col)
             .clean_location(loc_col)
             .extract_features(area_col)
             .add_calculations()
             .export_to_excel('Datos_Scraping', project))
        return self.df

# Ejemplo de uso:
# scraper = MarketScraper(url="https://ejemplo.com")
# df_final = scraper.run(project="ProyectoX")

# %%
# Ejemplo de uso:
url1 = "https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2825-gran-central-colonial-ii-cercado-de-lima-lima-lima-los-portales-departamentos"

scraper = MarketScraper(url=url1)
df_final = scraper.run(project="Proyecto1")
df_final
# Out:
# Guardando en C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO DE LIMA/Datos_Scraping Proyecto1.xlsx
# Exportación exitosa.
# Empty DataFrame
# Columns: [TITULO, Unidades_Disponibles, Modelo, Piso_Desde, Piso_Hasta, Total_Pisos, Dormitorios, Area_m2, Precio_Desde_Soles]
# Index: []

# %%
import re
import pandas as pd
import datetime
from bs4 import BeautifulSoup as BS
from selenium import webdriver

class MarketScraper:
    """
    Clase para extracción, limpieza y análisis de datos de proyectos inmobiliarios.
    """
    def __init__(self, url=None, df=None):
        self.url = url
        self.df = df
        self.soup = None

    def _init_driver(self):
        driver = webdriver.Chrome()
        driver.get(self.url)
        content = driver.page_source
        driver.quit()
        self.soup = BS(content, 'html.parser')

    def extract_data(self, tag: str, attrs: dict) -> list:
        items = self.soup.find_all(tag, attrs=attrs)
        return [el.text.strip() for el in items]

    def normalize_columns(self):
        self.df.columns = self.df.columns.str.upper()
        return self

    def debug_dormitorios(self) -> list:
        matches = self.soup.find_all(text=re.compile(r'Dormitoris?', re.IGNORECASE))
        return [str(m.parent) for m in matches]

    def extract_title_features(self, title_col: str = 'TITULO'):
        def _parse(titulo):
            u = re.search(r'(\d+) unidad?', titulo)
            unidades = int(u.group(1)) if u else None
            m = re.search(r'(\w+)\sPiso', titulo)
            modelo = m.group(1) if m else None
            ep = re.search(r'Entre\s*(\d+)\s*al\s*(\d+)', titulo)
            if ep:
                piso_desde, piso_hasta = int(ep.group(1)), int(ep.group(2))
                total_pisos = piso_hasta - piso_desde + 1
            else:
                pc = re.findall(r'Piso (\d+(?:, \d+)*)', titulo)
                if pc:
                    pisos_list = [int(p) for p in pc[0].split(', ')]
                    piso_desde, piso_hasta = min(pisos_list), max(pisos_list)
                    total_pisos = len(pisos_list)
                else:
                    piso_desde = piso_hasta = total_pisos = None
            d = re.search(r'(\d+) Dormitorios?', titulo)
            dormitorios = int(d.group(1)) if d else None
            a = re.search(r'Área ([\d.]+)', titulo)
            area = float(a.group(1)) if a else None
            p = re.search(r'Precio desde S/ ([\d,]+)', titulo)
            precio = float(p.group(1).replace(',', '')) if p else None
            return [unidades, modelo, piso_desde, piso_hasta, total_pisos, dormitorios, area, precio]
        cols = ['Unidades_Disponibles', 'Modelo', 'Piso_Desde', 'Piso_Hasta', 'Total_Pisos',
                'Dormitorios', 'Area_m2', 'Precio_Desde_Soles']
        title_df = pd.DataFrame(self.df[title_col].astype(str).apply(_parse).tolist(), columns=cols)
        self.df = pd.concat([self.df, title_df], axis=1)
        self.df.dropna(how='all', subset=cols, inplace=True)
        return self

    def _build_regex(self, before: str = None, after: str = None, price: bool = False) -> str:
        num = r"\d{1,3}(?:,\d{3})*" if price else r"\d+"
        if before and after:
            return rf"{re.escape(after)}\s*({num})\s*{re.escape(before)}"
        if after:
            return rf"{re.escape(after)}\s*({num})"
        if before:
            return rf"({num})\s*{re.escape(before)}"
        raise ValueError("Se requiere al menos 'before' o 'after'.")

    def find_number(self, col: str, before: str = None, after: str = None, price: bool = False) -> pd.Series:
        regex = self._build_regex(before, after, price)
        return self.df[col].apply(lambda x: int(re.search(regex, str(x)).group(1).replace(',', ''))
                                  if re.search(regex, str(x)) else None)

    def clean_price(self, col: str = 'PRECIO_DESDE'):
        if col in self.df.columns:
            s = self.df[col].astype(str)
            self.df['Moneda_soles'] = s.str.contains('S/').map({True: 'Soles', False: None})
            self.df['Moneda_dolares'] = s.str.contains('USD').map({True: 'Dólares', False: None})
            self.df['Precio_soles'] = s.where(self.df['Moneda_soles'].notnull()) \
                .str.extract(r"(\d+)\b")[0].astype(float) * 1000
            self.df['Precio_dolares'] = self.find_number(col, after='USD', price=True)
        return self

    def clean_location(self, col: str = 'UBICACION', districts: list = None):
        if col in self.df.columns:
            if districts is None:
                districts = ['Comas', 'Breña', 'Lima', 'Peru', 'Perú', 'San Miguel']
            def _clean(text):
                if not isinstance(text, str):
                    return None
                for d in districts:
                    text = re.sub(rf"\b{d}\b", '', text, flags=re.IGNORECASE)
                return re.sub(r"\s+", ' ', re.sub(r"[\.,;:!?]+$", '', text)).strip() or None
            self.df['Calle'] = self.df[col].apply(_clean)
        return self

    def extract_features(self, col: str = 'METRAJE'):
        if col in self.df.columns:
            keys = ['Unidades', 'Dormitorios', 'Metraje_desde', 'Metraje_hasta', 'Baños', 'Estacionamientos']
            patterns = [('un.', None), ('dorm.', None), ('a', 'dorm.'), ('m²', None), ('baño', None), ('esta', None)]
            for key, (before, after) in zip(keys, patterns):
                self.df[key] = pd.to_numeric(self.find_number(col, before=before, after=after), errors='coerce')
        return self

    def add_calculations(self):
        if 'Precio_soles' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_soles_desde'] = (self.df['Precio_soles'] / self.df['Metraje_hasta']).round()
        if 'Precio_soles' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_soles_hasta'] = (self.df['Precio_soles'] / self.df['Metraje_desde']).round()
        if 'Precio_dolares' in self.df and 'Metraje_hasta' in self.df:
            self.df['Precio m2_usd_desde'] = (self.df['Precio_dolares'] / self.df['Metraje_hasta']).round()
        if 'Precio_dolares' in self.df and 'Metraje_desde' in self.df:
            self.df['Precio m2_usd_hasta'] = (self.df['Precio_dolares'] / self.df['Metraje_desde']).round()
        return self

    def export_to_excel(self, filename: str, project: str):
        """
        Exporta DataFrame a Excel incluyendo fecha actual en nombre de archivo.
        """
        base = "C:/Users/diego.dinatale/OneDrive - Aenza/LOCAL_MACHINE/DATA_ANALYTICS/"
        fecha = datetime.datetime.now().strftime("%d_%m_%Y")
        nombre_file = f"{filename}_{fecha} {project}"
        path = f"{base}BD VIVA/DATA DEL MERCADO CON SCRAPPING/CERCADO especial/{nombre_file}.xlsx"
        print(f"Guardando en {path}")
        self.df.to_excel(path, index=False)
        print("Exportación exitosa.")
        return self

    def run(self, project: str, price_col: str = 'PRECIO_DESDE', loc_col: str = 'UBICACION', area_col: str = 'METRAJE') -> pd.DataFrame:
        self._init_driver()
        datos = self.extract_data('div', {'class': 'caption'})
        self.df = pd.DataFrame({'TITULO': datos})
        (self.normalize_columns()
             .extract_title_features()
             .clean_price(price_col)
             .clean_location(loc_col)
             .extract_features(area_col)
             .add_calculations()
             .export_to_excel('Datos_Scraping', project))
        return self.df
